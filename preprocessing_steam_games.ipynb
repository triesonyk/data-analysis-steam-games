# %% [markdown]
# ## import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# ## load dataset

# %%
raw = pd.read_csv('steam_games.csv')
raw.sample(5)
# Out:
#                       title  \
# 18639              Solo Fox
# 40504          Demon Hunter
# 50159  东方蝶梦志 交响组曲 ~ 梦中的钧天广乐
# 38698     欢迎回家-Welcome Home
# 15837                 Aztez
#
#                                                      url  \
# 18639  https://store.steampowered.com/app/1525650/Sol...
# 40504  https://store.steampowered.com/app/535530/Demo...
# 50159  https://store.steampowered.com/app/941440/_/?s...
# 38698  https://store.steampowered.com/app/1870020/Wel...
# 15837  https://store.steampowered.com/app/244750/Azte...
#
#                                                    image  release_date  \
# 18639  https://cdn.akamai.steamstatic.com/steam/apps/...  13 Feb, 2021
# 40504  https://cdn.akamai.steamstatic.com/steam/apps/...  29 Sep, 2016
# 50159  https://cdn.akamai.steamstatic.com/steam/apps/...  14 Sep, 2018
# 38698  https://cdn.akamai.steamstatic.com/steam/apps/...  14 Feb, 2022
# 15837  https://cdn.akamai.steamstatic.com/steam/apps/...   1 Aug, 2017
#
#                   platforms discount_rate original_price discounted_price  \
# 18639               Windows           NaN      Rp 24 999              NaN
# 40504               Windows           NaN     Rp 135 999              NaN
# 50159                   NaN           NaN      Rp 24 999              NaN
# 38698               Windows           NaN      Rp 52 999              NaN
# 15837  Windows,Mac OS,Linux           NaN     Rp 135 999              NaN
#
#                                               developer  \
# 18639                                   "RevDay Studio"
# 40504  Beijing Skyline Interaction Technology Co., Ltd.
# 50159                                              弦语蝶梦
# 38698                                              橙光游戏
# 15837                                   Team Colorblind
#
#                                               publisher  overall_reviews  \
# 18639                                   "RevDay Studio"         Positive
# 40504  Beijing Skyline Interaction Technology Co., Ltd.   8 user reviews
# 50159                                              弦语蝶梦   5 user reviews
# 38698                                              橙光游戏              NaN
# 15837                                   Team Colorblind  Mostly Positive
#
#                                             text_reviews  \
# 18639  - 100% of the 13 user reviews for this game ar...
# 40504       - Need more user reviews to generate a score
# 50159       - Need more user reviews to generate a score
# 38698                                                NaN
# 15837  - 76% of the 130 user reviews for this game ar...
#
#                                              description  \
# 18639            2D Indie-platformer about the fox Solo.
# 40504  Demon hunter it is a kind of virtual reality R...
# 50159                                                NaN
# 38698  This is a secret room to escape burning brain ...
# 15837  Aztez is a highly stylized, brutally satisfyin...
#
#                                                     tags  \
# 18639  Adventure,2D Platformer,2D,Platformer,Linear,N...
# 40504                            Action,Adventure,RPG,VR
# 50159                                Action,Indie,Casual
# 38698  Interactive Fiction,Puzzle,Casual,Mystery,Adve...
# 15837  Action,Indie,Strategy,Beat 'em up,Character Ac...
#
#                        processor          ram  \
# 18639                 intel Atom   256 MB RAM
# 40504                    i5 6500     4 GB RAM
# 50159                        NaN          NaN
# 38698   1Ghz or faster processor     1 GB RAM
# 15837          2.4 GHz Dual core     2 GB RAM
#
#                                           graphic_card            rating  \
# 18639                                              NaN               NaN
# 40504                                           GTX970               NaN
# 50159                                              NaN               NaN
# 38698                                       512MB VRAM               NaN
# 15837   Intel HD 2000, NVIDIA GeForce 210, or ATI 4850  Rating for: PEGI
#
#                                             language  metacriticts
# 18639  English,French,German,Spanish - Spain,Russian           NaN
# 40504                                        English           NaN
# 50159                                            NaN           NaN
# 38698                     English,Simplified Chinese           NaN
# 15837                                        English          81.0

# %% [markdown]
# ## data understanding

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68468 entries, 0 to 68467
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             68468 non-null  object
#  1   url               68468 non-null  object
#  2   image             68468 non-null  object
#  3   release_date      62160 non-null  object
#  4   platforms         66194 non-null  object
#  5   discount_rate     5401 non-null   object
#  6   original_price    67795 non-null  object
#  7   discounted_price  5401 non-null   object
#  8   developer         61855 non-null  object
#  9   publisher         56815 non-null  object
#  10  overall_reviews   55479 non-null  object
#  11  text_reviews      55479 non-null  object
#  12  description       40956 non-null  object
#  13  tags              61039 non-null  object
#  14  processor         55299 non-null  object
#  15  ram               55091 non-null  object
#  16  graphic_card      51361 non-null  object
#  17  rating            13428 non-null  object
#  18  language          59912 non-null  object
#  19  metacriticts      1881 non-null   float64
# dtypes: float64(1), object(19)
# memory usage: 10.4+ MB

# %% [markdown]
# Observations:
# - `url`,`image`,`discount_rate`,`discounted_price`,`description` drop
# - `release_date` extract month and year
# - `platfoms`,`developer`,`publisher`,`tags` split
# - `original_price` change data type (extract price)
# - `text_reviews` extract rating (`user_rating`) and total user reviews (`total_reviews`)
# - `language` extract number of language (`language`)
# - `metacriticts` too much missing values, drop

# %%
raw.describe()
# Out:
#        metacriticts
# count   1881.000000
# mean      80.971823
# std        4.458169
# min       75.000000
# 25%       77.000000
# 50%       80.000000
# 75%       84.000000
# max       97.000000

# %%
raw.describe(include='object')
# Out:
#                     title                                                url  \
# count               68468                                              68468
# unique              64887                                              68468
# top     Game + Soundtrack  https://store.steampowered.com/app/730/Counter...
# freq                   13                                                  1
#
#                                                     image  release_date  \
# count                                               68468         62160
# unique                                              65033          3894
# top     https://cdn.akamai.steamstatic.com/steam/apps/...  14 Oct, 2020
# freq                                                    6           146
#
#        platforms discount_rate original_price discounted_price  \
# count      66194          5401          67795             5401
# unique        12            89           4591             1500
# top      Windows          -50%      Rp 69 999         Rp 4 249
# freq       44961          1006           5108              329
#
#                       developer publisher overall_reviews  \
# count                     61855     56815           55479
# unique                    24765     20134              18
# top     Ubisoft - San Francisco    Degica   Very Positive
# freq                       1167      1049           11078
#
#                                         text_reviews  \
# count                                          55479
# unique                                         13440
# top     - Need more user reviews to generate a score
# freq                                           15169
#
#                                     description    tags  \
# count                                     40956   61039
# unique                                    39011   40137
# top     Minimal physical puzzle with explosions  Action
# freq                                         15    1715
#
#                                                 processor        ram  \
# count                                               55299      55091
# unique                                              12423        859
# top     2.66 GHz Intel Core2 Duo E6750 or 2.8 GHz AMD ...   4 GB RAM
# freq                                                  801      13411
#
#                                              graphic_card            rating  \
# count                                               51361             13428
# unique                                              14567                 1
# top     256 MB DirectX 9 / NVIDIA® GeForce® 8600 GT or...  Rating for: PEGI
# freq                                                 1167             13428
#
#        language
# count     59912
# unique     7879
# top     English
# freq      24115

# %% [markdown]
# observations:
# - `rating` data is wrong, consider drop or rescrape data
# - `tags` too much unique value, consider to create new columns tag that has been aggregated

# %% [markdown]
# ## data preprocessing (format)

# %% [markdown]
# ### drop duplicates and uninformative columns

# %%
df_drop = raw.copy()
df_drop.drop_duplicates(subset='title',inplace=True)
df_drop['title'].duplicated().sum()
# Out:
# 0

# %%
drop = ['url','image','discount_rate','discounted_price','description','metacriticts','processor','graphic_card'] #these variables unable to show any kind of valuable information that can be used for current analysis and machine learning model, consider to be used for other analysis
df_drop = df_drop.drop(labels=drop,axis=1)
df_drop.sample(10)
# Out:
#                                                  title  release_date  \
# 33416          MONSTER HUNTER RISE - "Attack" pose set  12 Jan, 2022
# 48100            Merrily Perilly Soundtrack + Art Book  23 Oct, 2018
# 27535                            Guardians of Greyrock   2 Apr, 2021
# 40941  Neptunia Virtual Stars - Game Club Project Pack  29 Apr, 2021
# 17791                                     PD Howler 10   6 May, 2016
# 11734         绽于枝垂樱下~Flowering Across the Hakugyokurou  12 Jul, 2019
# 19607                                    The foreigner   5 Feb, 2020
# 50030                                      Deeply Dark  31 May, 2021
# 26384                                          Luminos  11 Apr, 2019
# 24412                                  Book of Shadows   1 Nov, 2020
#
#             platforms original_price  \
# 33416         Windows      Rp 28 999
# 48100  Windows,Mac OS      Rp 17 499
# 27535         Windows   Free to Play
# 40941         Windows      Rp 32 999
# 17791         Windows      Rp 82 999
# 11734         Windows       Rp 8 499
# 19607         Windows       Rp 8 499
# 50030         Windows      Rp 99 999
# 26384         Windows            NaN
# 24412         Windows      Rp 32 999
#
#                                                developer  \
# 33416                                   CAPCOM Co., Ltd.
# 48100                                      Squiddershins
# 27535                                         MythicWare
# 40941                         Idea Factory,Compile Heart
# 17791  Daniel Ritchie - PDHowler.com,Philip Staiger -...
# 11734                                               凝冰剑斩
# 19607                                          HCGstudio
# 50030                                             DALESI
# 26384                                           dev4play
# 24412                                             Enoops
#
#                               publisher  overall_reviews  \
# 33416                  CAPCOM Co., Ltd.   1 user reviews
# 48100                               NaN              NaN
# 27535  Dark Illusions Entertainment LLC            Mixed
# 40941                               NaN              NaN
# 17791                               KPL         Positive
# 11734                              凝冰剑斩    Very Positive
# 19607                         HCGstudio         Positive
# 50030                            DALESI   3 user reviews
# 26384                          dev4play         Positive
# 24412                            Enoops  Mostly Positive
#
#                                             text_reviews  \
# 33416       - Need more user reviews to generate a score
# 48100                                                NaN
# 27535  - 45% of the 20 user reviews for this game are...
# 40941                                                NaN
# 17791  - 92% of the 14 user reviews for this software...
# 11734  - 96% of the 112 user reviews for this game ar...
# 19607  - 86% of the 22 user reviews for this game are...
# 50030       - Need more user reviews to generate a score
# 26384  - 100% of the 15 user reviews for this game ar...
# 24412  - 78% of the 33 user reviews for this game are...
#
#                                                     tags          ram  \
# 33416                   Action,RPG,Co-op,Action RPG,JRPG     8 GB RAM
# 48100                                              Indie    34 MB RAM
# 27535  Strategy,Card Game,Adventure,Indie,Casual,Card...     8 GB RAM
# 40941                               Action,Adventure,RPG     4 GB RAM
# 17791  Design & Illustration,Photo Editing,Animation ...     2 GB RAM
# 11734  RPG,Indie,RPGMaker,Female Protagonist,LGBTQ+,V...   512 MB RAM
# 19607  Adventure,Indie,Casual,Nudity,Sexual Content,G...     2 GB RAM
# 50030  Early Access,Indie,Roguelike,Inventory Managem...     6 GB RAM
# 26384                                       Indie,Casual     2 GB RAM
# 24412  Adventure,Casual,Puzzle,Point & Click,Arcade,E...     2 GB RAM
#
#                  rating                                           language
# 33416  Rating for: PEGI  English,French,Italian,German,Spanish - Spain,...
# 48100               NaN                                            English
# 27535               NaN                                            English
# 40941               NaN               English,Japanese,Traditional Chinese
# 17791               NaN                                            English
# 11734               NaN                         English,Simplified Chinese
# 19607               NaN     English,Simplified Chinese,Traditional Chinese
# 50030               NaN                    English,Spanish - Latin America
# 26384               NaN  English,French,Italian,German,Spanish - Spain,...
# 24412               NaN               English,Russian,French,German,Polish

# %% [markdown]
# ### data extraction and formatting

# %% [markdown]
# #### extract `month` and `year`

# %%
#define function to extract year
def extract_year(x):
    year = None
    if type(x) == list:
        for i in x:
            if len(i) == 4:
                year = i
                return year
            else: 
                year = None
        return year
    else:
        year = x
    return year

# %%
#df_drop[['date','month','year']] = df_drop['release_date'].str.split(' ', n=2 , expand=True)
df_extract = df_drop.copy()
month = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
#df_extract['year'] = df_extract['release_date'].str[-4:].apply(pd.to_numeric, errors=('coerce')) 
df_extract['year'] = df_extract['release_date'].str.findall('(\d+)').apply(lambda x: extract_year(x)).astype(float)
df_extract['month'] = df_extract['release_date'].str.findall("[a-zA-Z]+").str[0]
df_extract['month'] = df_extract['month'].replace(['August','June'],['Aug','Jun'])
df_extract.loc[~df_extract['month'].isin(month),'month'] = None
df_extract = df_extract.drop('release_date', axis=1) #drop release date
df_extract.sample(5)
# Out:
#                                              title             platforms  \
# 38306                                 Jurisdiction               Windows
# 63774          Would you like to run an idol café?         Windows,Linux
# 66583                                 Say No! More        Windows,Mac OS
# 53659  Aerofly FS 2 - Orbx - Eagle County Colorado  Windows,Mac OS,Linux
# 12202                 DW8XLCE - OLD COSTUME PACK 3               Windows
#
#       original_price                   developer                   publisher  \
# 38306     Rp 108 999                Meteor Shock                Meteor Shock
# 63774      Rp 69 999         StarlightTree Games                Winged Cloud
# 66583      Rp 95 999               Studio Fizbin       Thunderful Publishing
# 53659     Rp 139 999                        Orbx                       IPACS
# 12202      Rp 25 999  KOEI TECMO GAMES CO., LTD.  KOEI TECMO GAMES CO., LTD.
#
#       overall_reviews                                       text_reviews  \
# 38306  8 user reviews       - Need more user reviews to generate a score
# 63774           Mixed  - 60% of the 15 user reviews for this game are...
# 66583   Very Positive  - 91% of the 399 user reviews for this game ar...
# 53659  5 user reviews       - Need more user reviews to generate a score
# 12202        Positive  - 81% of the 11 user reviews for this game are...
#
#                                                     tags          ram  \
# 38306  Strategy,Simulation,Management,RTS,Sandbox,Cri...     8 GB RAM
# 63774  Visual Novel,Simulation,Anime,Cute,Dating Sim,...   250 MB RAM
# 66583  Indie,Funny,Casual,Comedy,Singleplayer,Cute,Co...     4 GB RAM
# 53659                                   Simulation,Indie          NaN
# 12202                                             Action   256 MB RAM
#
#                  rating                                           language  \
# 38306               NaN                                            English
# 63774               NaN                         English,Simplified Chinese
# 66583               NaN  English,French,Italian,German,Spanish - Spain,...
# 53659               NaN                              English,German,French
# 12202  Rating for: PEGI                              English,French,German
#
#          year month
# 38306  2021.0   Mar
# 63774  2021.0   Jun
# 66583  2021.0   Apr
# 53659  2018.0   Jan
# 12202  2014.0   Aug

# %% [markdown]
# #### extract `user_rating` and `total_reviews`

# %%
df_extract_2 = df_extract.copy()
df_extract_2['text_reviews'] = df_extract_2['text_reviews'].str.replace(',','')
df_extract_2['user_rating'] = df_extract_2['text_reviews'].str.findall('(\d+)').str[0].astype(float)
df_extract_2['total_review'] = df_extract_2['text_reviews'].str.findall('(\d+)').str[1].astype(float)
df_extract_2 = df_extract_2.drop('text_reviews',axis=1)
df_extract_2.sample(5)
# Out:
#                                                    title  \
# 52717                     BLOCK HEIST: Robbery Simulator
# 15909                                             DELUGE
# 16685  Dungeon Defenders - Etherian Holiday Extravaganza
# 7155                            奇幻与砍杀2 Fantasy & Blade Ⅱ
# 7539                                           Tower! 3D
#
#                   platforms original_price             developer  \
# 52717               Windows       Rp 8 499          Cyber Gaming
# 15909               Windows      Rp 39 999              Riggy2k3
# 16685  Windows,Mac OS,Linux      Rp 17 499  Trendy Entertainment
# 7155                Windows      Rp 59 999                    绝汪
# 7539                Windows      Rp 64 999             FeelThere
#
#                   publisher  overall_reviews  \
# 52717          Cyber Gaming   8 user reviews
# 15909              Riggy2k3         Positive
# 16685  Trendy Entertainment            Mixed
# 7155                     绝汪  Mostly Positive
# 7539              FeelThere            Mixed
#
#                                                     tags          ram  \
# 52717  Action,Crime,Heist,Simulation,Third-Person Sho...     4 GB RAM
# 15909  RPG,Emotional,Old School,Dark Fantasy,Pixel Gr...   256 MB RAM
# 16685                                   Indie,Action,RPG          NaN
# 7155   Action,Casual,Adventure,RPG,Indie,Strategy,RPG...     4 GB RAM
# 7539   Simulation,Flight,Multiplayer,Management,Casua...     8 GB RAM
#
#                  rating                                           language  \
# 52717               NaN  English,Russian,French,Italian,German,Spanish ...
# 15909               NaN                                            English
# 16685  Rating for: PEGI                                            English
# 7155                NaN                         English,Simplified Chinese
# 7539                NaN                                            English
#
#          year month  user_rating  total_review
# 52717  2021.0   Dec          NaN           NaN
# 15909  2021.0   Nov        100.0          15.0
# 16685  2011.0   Dec         68.0          16.0
# 7155   2019.0   Oct         74.0         109.0
# 7539   2020.0   Jul         56.0          50.0

# %% [markdown]
# #### extract `supported_language`

# %%
df_extract_3 = df_extract_2.copy()
df_extract_3['supported_language'] = df_extract_3['language'].str.split(',').apply(lambda x: len(x) if type(x) == list else x)
#df_extract_3['english_language'] = df_extract_3['language'].str.lower().str.contains('english')
df_extract_3 = df_extract_3.drop('language',axis=1)
df_extract_3.sample(5)
# Out:
#                                            title      platforms  \
# 17541    Under Domain - Alien Invasion Simulator        Windows
# 38747                                   Toasted!        Windows
# 43865  Pride of Nations: American Civil War 1862        Windows
# 52932                                    Kaboom!  Windows,Linux
# 23798      Ride 2 Kawasaki and Ducati Bonus Pack        Windows
#
#       original_price                        developer  \
# 17541      Rp 48 999                        Playlearn
# 38747      Rp 64 999  Polygon Dust Entertainment Ltd.
# 43865      Rp 35 999                            Ageod
# 52932      Rp 52 999               CubeCoders Limited
# 23798      Rp 32 999                 Milestone S.r.l.
#
#                              publisher overall_reviews  \
# 17541                        Playlearn           Mixed
# 38747  Polygon Dust Entertainment Ltd.             NaN
# 43865                  Slitherine Ltd.  1 user reviews
# 52932               CubeCoders Limited  1 user reviews
# 23798                 Milestone S.r.l.           Mixed
#
#                                                     tags           ram rating  \
# 17541  Board Game,Aliens,Villain Protagonist,Time Man...      4 GB RAM    NaN
# 38747  Local Co-Op,Action,Vehicular Combat,Party,Co-o...      8 GB RAM    NaN
# 43865                                           Strategy        2 GB (    NaN
# 52932  Action,Casual,Arcade,Multiplayer,Battle Royale...   4096 MB RAM    NaN
# 23798                           Simulation,Racing,Sports      4 GB RAM    NaN
#
#          year month  user_rating  total_review  supported_language
# 17541  2020.0   Oct         50.0          69.0                 2.0
# 38747  2022.0   Mar          NaN           NaN                 1.0
# 43865  2011.0   Aug          NaN           NaN                 4.0
# 52932  2021.0   Jul          NaN           NaN                 1.0
# 23798  2016.0   Oct         64.0          17.0                 6.0

# %% [markdown]
# #### extract `price`

# %%
df_price = df_extract_3.copy()
df_price['price'] = df_price['original_price'].str.lower().str.strip('rp ').str.replace(' ','').astype(int,errors='ignore')
df_price.loc[df_price['price'].str.contains('free|demo|season|third|now',na=False),'price'] = 0
df_price['price'] = df_price['price'].astype(float)
df_price = df_price.drop('original_price',axis=1)
df_price.sample(5)
# Out:
#                                                    title  \
# 23557                                           Megalith
# 53049  Neptunia Virtual Stars - Unlock All BeatTik Da...
# 15507                                         Townopolis
# 38849      White Day - Christmas Costume - Ji-Hyeon Seol
# 63790                                             Zero-K
#
#                   platforms                   developer  \
# 23557               Windows      Disruptive Games, Inc.
# 53049               Windows  Idea Factory,Compile Heart
# 15507  Windows,Mac OS,Linux               Lonely Troops
# 38849               Windows                SONNORI Corp
# 63790               Windows                 Zero-K Team
#
#                         publisher  overall_reviews  \
# 23557      Disruptive Games, Inc.            Mixed
# 53049  Idea Factory International              NaN
# 15507               Lonely Troops  Mostly Positive
# 38849          PQube,SONNORI Corp   4 user reviews
# 63790                 Zero-K Team    Very Positive
#
#                                                     tags        ram rating  \
# 23557  Action,VR,MOBA,Multiplayer,Hero Shooter,Tactic...   8 GB RAM    NaN
# 53049                               Action,Adventure,RPG   4 GB RAM    NaN
# 15507  Casual,Simulation,Strategy,Indie,Time Manageme...   1 GB RAM    NaN
# 38849                             Action,Adventure,Indie   4 GB RAM    NaN
# 63790  Strategy,Free to Play,RTS,Indie,Simulation,Mul...   4 GB RAM    NaN
#
#          year month  user_rating  total_review  supported_language     price
# 23557  2020.0   May         65.0          49.0                 1.0  119999.0
# 53049  2021.0   Mar          NaN           NaN                 3.0   17499.0
# 15507  2016.0   Apr         75.0          52.0                 6.0   32999.0
# 38849  2017.0   Dec          NaN           NaN                 9.0   17499.0
# 63790  2018.0   Apr         82.0          34.0                 1.0       0.0

# %% [markdown]
# #### extract `rated_by_pegi`

# %%
df_pegi = df_price.copy()
df_pegi['pegi_rated'] = np.where(df_pegi['rating']=='Rating for: PEGI', 1, 0)
df_pegi = df_pegi.drop('rating',axis=1)
df_pegi.sample(5)
# Out:
#                                                    title  \
# 66618  Borderlands 3: Multiverse Disciples of the Vau...
# 63978                      Sentience: The Android's Tale
# 64567                                        Neon Chrome
# 55880              Trainz 2019 DLC: Avery - Drexel Route
# 22979                                             Becalm
#
#                   platforms           developer     publisher overall_reviews  \
# 66618               Windows    Gearbox Software            2K           Mixed
# 63978        Windows,Mac OS  Pilgrim Adventures  GrabTheGames   Very Positive
# 64567  Windows,Mac OS,Linux          10tons Ltd    10tons Ltd   Very Positive
# 55880        Windows,Mac OS           N3V Games           NaN  2 user reviews
# 22979  Windows,Mac OS,Linux        Colorfiction  Colorfiction   Very Positive
#
#                                                     tags           ram  \
# 66618             Action,RPG,Gore,Violent,Sexual Content      6 GB RAM
# 63978  Adventure,Indie,Sci-fi,Multiple Endings,Futuri...      2 GB RAM
# 64567  Cyberpunk,Twin Stick Shooter,Action,Action Rog...   2048 MB RAM
# 55880                                         Simulation      4 GB RAM
# 22979  Free to Play,Casual,Indie,Relaxing,Nature,Beau...      2 GB RAM
#
#          year month  user_rating  total_review  supported_language     price  \
# 66618  2021.0   Apr         46.0          15.0                11.0  150000.0
# 63978  2017.0   Jun         89.0          76.0                 1.0   31000.0
# 64567  2016.0   Apr         94.0         474.0                 6.0  115999.0
# 55880  2019.0   Jan          NaN           NaN                 6.0  139999.0
# 22979  2019.0   Jan         84.0         332.0                29.0       0.0
#
#        pegi_rated
# 66618           1
# 63978           0
# 64567           1
# 55880           0
# 22979           0

# %% [markdown]
# extract `windows`, `mac`, and `linux`

# %%
df_platform = df_pegi.copy()
df_platform['windows'] = np.where(df_platform['platforms'].str.contains('Windows',na=False), 1, 0)
df_platform['mac'] = np.where(df_platform['platforms'].str.contains('Mac OS',na=False), 1, 0)
df_platform['linux'] = np.where(df_platform['platforms'].str.contains('Linux',na=False), 1, 0)
df_platform['VR'] = np.where(df_platform['platforms'].str.contains('VR Supported',na=False), 1, 0)
df_platform = df_platform.drop('platforms',axis=1)
df_platform.sample(10)
# Out:
#                                                title  \
# 53341  Rocksmith® 2014 – Jimi Hendrix - “Foxey Lady”
# 15502                               Complete the set
# 50246       Riddles of the Owls Kingdom - Soundtrack
# 38180                                          POG 7
# 63765                               Pixel Shopkeeper
# 48924                                         Zephyr
# 16168                                   Dashy Square
# 51730              The Banner Saga 3 - Eternal Arena
# 57828           Infinite World: Randomize everything
# 49221                              Dimension Shifter
#
#                              developer             publisher  overall_reviews  \
# 53341          Ubisoft - San Francisco                   NaN   1 user reviews
# 15502                              NaN                   NaN              NaN
# 50246                        DigiMight                   NaN              NaN
# 38180              Cute Hannah's Games   Cute Hannah's Games   1 user reviews
# 63765             Pixel Prototype, LLC  Pixel Prototype, LLC  Mostly Positive
# 48924              New World Computing              Ziggurat   1 user reviews
# 16168  Kastriot Sulejmani,Logan Gerrol             KasSanity    Very Positive
# 51730                            Stoic           Versus Evil   5 user reviews
# 57828                              Vik           VicX Studio            Mixed
# 49221    Eyexapp Play,Eyexapp Creative               Eyexapp   1 user reviews
#
#                                                     tags          ram    year  \
# 53341                                  Casual,Simulation     2 GB RAM  2014.0
# 15502                                                NaN          NaN     NaN
# 50246                          Indie,Casual,Free to Play   512 MB RAM  2018.0
# 38180  Casual,Side Scroller,2D,Cute,Family Friendly,I...     2 GB RAM  2022.0
# 63765  Simulation,Indie,Pixel Graphics,Strategy,Adven...     1 GB RAM  2017.0
# 48924  Combat Racing,FPS,Pixel Graphics,Futuristic,Dy...   256 MB RAM  2021.0
# 16168  Indie,Action,Music,Difficult,Great Soundtrack,...   512 MB RAM  2016.0
# 51730                                 Strategy,RPG,Indie     2 GB RAM  2018.0
# 57828  Adventure,Indie,RPG,Action,Survival,Open World...     4 GB RAM  2018.0
# 49221  Action-Adventure,Adventure,2D Platformer,Pixel...     1 GB RAM  2022.0
#
#       month  user_rating  total_review  supported_language     price  \
# 53341   Dec          NaN           NaN                 6.0   35000.0
# 15502  None          NaN           NaN                 NaN  247198.0
# 50246   Oct          NaN           NaN                 4.0   24999.0
# 38180   Feb          NaN           NaN                29.0   17499.0
# 63765   Jul         78.0         140.0                 1.0   52999.0
# 48924   Feb          NaN           NaN                 1.0   52999.0
# 16168   Apr         84.0         109.0                 9.0   24999.0
# 51730   Dec          NaN           NaN                10.0   33939.0
# 57828   Jun         42.0          54.0                 1.0    8499.0
# 49221   Jan          NaN           NaN                 1.0   39999.0
#
#        pegi_rated  windows  mac  linux  VR
# 53341           1        1    1      0   0
# 15502           0        1    0      0   0
# 50246           0        1    1      0   0
# 38180           0        1    0      0   0
# 63765           0        1    1      1   0
# 48924           0        1    1      0   0
# 16168           1        1    1      0   0
# 51730           0        1    1      0   0
# 57828           0        1    0      0   0
# 49221           0        1    0      0   0

# %% [markdown]
# #### remap `ram`

# %%
df_platform['ram'][0]
# Out:
# ' 2 GB RAM'

# %%
df_ram = df_platform.copy()
df_ram.loc[df_ram['ram'].str.lower().str.contains('16.0 gb', na=False),'ram'] = '16 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('12.00 gb', na=False),'ram'] = '12 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('10 gb', na=False),'ram'] = '10 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('9 gb|9 gb', na=False),'ram'] = '9 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('8 gb|8000 mb|８ gb|8gb|8.0 gb|8+', na=False),'ram'] = '8 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('7 gb', na=False),'ram'] = '7 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('6 gb|6000 mb|６ gb', na=False),'ram'] = '6 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('5 gb|5000 mb', na=False),'ram'] = '5 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('4 gb|4096 mb|4000 mb|4gb|４ gb|4.00 gb|4g|4 ram gb', na=False),'ram'] = '4 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('3 gb|3000 mb|3 go mb|3gb', na=False),'ram'] = '3 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('2 gb|2048|2000 mb|2gb|1536 mb|2.0 gb|2000 gb|２ gb|1.5gb|2.0gb|2g', na=False),'ram'] = '2 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('1 gb|1024|1000 mb|1gb|800 mb|750 mb|1280 mb|700 mb|900 mb|１ gb|1+', na=False),'ram'] = '1 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('512|500 mb|400 mb|512mb|600 mb|597 mb|320 mb|420 mb|500mb|349 mb', na=False),'ram'] = '512 MB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('256 gb|200 mb|300 mb|250 mb|256mb|220 mb|256 ram', na=False),'ram'] = '256 MB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('128 mb|64m|70 mb|100 mb|150 mb|16 mb|8 mb|2 mb|1 mb|4 mb|50 mb|3 mb|6 mb|10 mb|128mb|80 mb|4 ram mb|30 mb|40 mb|25 mb|5 mb|120 mb|64 mb|90 mb|60 mb|95 mb|65 mb|64mb|16mb|100以上|32mb|97 mb|20 mb|99 mb|4mb|69 mb|59 mb', na=False),'ram'] = '<128 MB'
df_ram.loc[~df_ram['ram'].str.lower().str.contains('16 gb|12 gb|10 gb|9 gb|8 gb|7 gb|6 gb|5 gb|4 gb|3 gb|2 gb|1 gb|512 mb|256 mb|<128 mb', na=False),'ram'] = 'Unknown'
df_ram['ram'].value_counts()
# Out:
# 4 GB       13515
# 1 GB       13299
# 2 GB       12720
# Unknown    11840
# 8 GB        7941
# <128 MB     2853
# 6 GB        1946
# 3 GB         658
# 5 GB         109
# 7 GB           4
# 9 GB           2
# Name: ram, dtype: int64

# %%
df_ram.sample(10)
# Out:
#                                                    title  \
# 8460                                       IRON GUARD VR
# 48557                                      Pac vs Ghosts
# 38613                         Fate/EXTELLA - Cheerleader
# 40347                           Fantasy Memory Card Game
# 42468      BLUE REFLECTION - Arland Maid Costumes (Lime)
# 9954                                   House Sketcher 3D
# 51691  Pac-Man Championship Edition DX+: Big Eater Co...
# 36035               Guts and Glory - Original Soundtrack
# 5426                                 A Street Cat's Tale
# 7981   Raptor: Call of the Shadows (1994 Classic Edit...
#
#                             developer                        publisher  \
# 8460                     Xlab Digital                     Xlab Digital
# 48557                        Pix Arts                         Pix Arts
# 38613                  Marvelous Inc.  XSEED Games,Marvelous USA, Inc.
# 40347              Boogygames Studios               Boogygames Studios
# 42468      KOEI TECMO GAMES CO., LTD.       KOEI TECMO GAMES CO., LTD.
# 9954                 Sebastian Kemper                 Sebastian Kemper
# 51691  Mine Loader Software Co., Ltd.       BANDAI NAMCO Entertainment
# 36035                          HakJak                        tinyBuild
# 5426                         feemodev                    CFK Co., Ltd.
# 7981                   Cygnus Studios             Apogee Entertainment
#
#       overall_reviews                                               tags  \
# 8460    Very Positive  VR,Tower Defense,Strategy,RTS,Sci-fi,Action,Ro...
# 48557  2 user reviews  Action,Casual,Arcade,Classic,Cartoon,3D Platfo...
# 38613  1 user reviews                                             Action
# 40347  1 user reviews  Card Game,Board Game,Puzzle,Point & Click,Matc...
# 42468             NaN                                                RPG
# 9954            Mixed  Simulation,Design & Illustration,Building,Soft...
# 51691  9 user reviews                                             Action
# 36035  5 user reviews  Action,Indie,Casual,Racing,Gore,Violent,Soundt...
# 5426    Very Positive  Indie,Simulation,Adventure,Cats,Pixel Graphics...
# 7981    Very Positive   Action,Shoot 'Em Up,Classic,2D,Old School,1990's
#
#            ram    year month  user_rating  total_review  supported_language  \
# 8460      4 GB  2021.0   Sep         96.0          50.0                 5.0
# 48557  Unknown  2020.0   Jul          NaN           NaN                 1.0
# 38613     4 GB  2017.0   Jul          NaN           NaN                 4.0
# 40347     1 GB  2020.0   Mar          NaN           NaN                 1.0
# 42468     4 GB  2017.0   Sep          NaN           NaN                 3.0
# 9954      4 GB  2021.0   Dec         46.0          13.0                27.0
# 51691     1 GB  2013.0   Sep          NaN           NaN                 5.0
# 36035  Unknown  2018.0   Jul          NaN           NaN                 NaN
# 5426      2 GB  2019.0   Sep         96.0         162.0                 4.0
# 7981      2 GB  2014.0   May         93.0         101.0                 1.0
#
#          price  pegi_rated  windows  mac  linux  VR
# 8460   95999.0           0        1    0      0   0
# 48557  24999.0           0        1    1      0   0
# 38613  18999.0           0        1    0      0   0
# 40347   8499.0           0        1    0      0   0
# 42468  55999.0           1        1    0      0   0
# 9954   69999.0           0        1    1      0   0
# 51691  20000.0           1        1    0      0   0
# 36035  39999.0           0        0    0      0   0
# 5426   39999.0           0        1    1      0   0
# 7981   45999.0           0        1    1      0   0

# %% [markdown]
# #### remap `overall_reviews`

# %%
df_or = df_ram.copy()
df_or.loc[~df_or['overall_reviews'].str.contains('Positive|Negative|Very|Overwhelmingly|Mixed|Mostly', na=False),'overall_reviews'] = '<10 reviews'
df_or['overall_reviews'].value_counts()
# Out:
# <10 reviews                26699
# Very Positive              10628
# Mixed                       9458
# Positive                    9079
# Mostly Positive             6749
# Mostly Negative             1559
# Overwhelmingly Positive      417
# Negative                     234
# Very Negative                 57
# Overwhelmingly Negative        7
# Name: overall_reviews, dtype: int64

# %%
df_or.sample(5)
# Out:
#                                                    title  \
# 13820          Beach Buggy Racing 2: Hot Wheels™ Edition
# 37290     LET IT DIE -(7 Mil Downloads)100 Death Metals-
# 12665                       Ragnar's Chinese Memory Game
# 42842  灵魂筹码 - 幽伶刀马花旦套装 Soul at Stake - "Tao Ma Tan" T...
# 19005                              Gabe Newell Simulator
#
#                                                developer  \
# 13820                                                NaN
# 37290  GRASSHOPPER MANUFACTURE INC.,SUPERTRICK  GAMES...
# 12665                                Ragnar Brynjúlfsson
# 42842                                   Chongming Studio
# 19005                                      Antonio Renna
#
#                                  publisher overall_reviews  \
# 13820                                  NaN     <10 reviews
# 37290  GungHo Online Entertainment America     <10 reviews
# 12665                  Ragnar Brynjúlfsson        Positive
# 42842                     Chongming Studio     <10 reviews
# 19005                        Antonio Renna           Mixed
#
#                                                     tags      ram    year  \
# 13820                                                NaN  Unknown     NaN
# 37290  Action,Free to Play,Gore,Violent,Nudity,Sexual...     8 GB  2021.0
# 12665  Education,Card Game,Board Game,Hand-drawn,Fore...     4 GB  2020.0
# 42842  Action,RPG,Indie,Gore,Violent,Multiplayer,Surv...     8 GB  2020.0
# 19005  Memes,Action,Simulation,Indie,Adventure,Parody...     2 GB  2015.0
#
#       month  user_rating  total_review  supported_language     price  \
# 13820  None          NaN           NaN                 NaN  161098.0
# 37290   Sep          NaN           NaN                10.0  119999.0
# 12665   Aug        100.0          10.0                 3.0   48999.0
# 42842   Jun          NaN           NaN                 2.0  169999.0
# 19005   Dec         49.0         461.0                 1.0   19999.0
#
#        pegi_rated  windows  mac  linux  VR
# 13820           0        1    0      0   0
# 37290           1        1    0      0   0
# 12665           0        1    0      1   0
# 42842           0        1    0      0   0
# 19005           0        1    1      1   0

# %% [markdown]
# #### reformat and remap `tags`

# %%
df_tags = df_or.copy()
df_tags.loc[df_tags['tags'].isna()==True,'tags'] = 'No Tags'
df_tags['tags'] = df_tags['tags'].str.split(',')
#df_tags['tags'] = df_tags['tags'].replace(',', '","')
#df_tags['tags'] = '["' + df_tags['tags'] + '"]'
df_tags.sample(10)
# Out:
#                                                    title  \
# 10768                         Injustice™ 2 - Black Manta
# 28716                                             Catsby
# 28069                                           Archamon
# 21558                      Cloudpunk + Soundtrack Bundle
# 30148                                        Data Bundle
# 48777                                      Xtreme Typing
# 33266  MONSTER HUNTER RISE - "Canyne Tail" Hunter lay...
# 20614                                Animal and Aquarist
# 59525                                Ho-Ho-Home Invasion
# 31118                                     Gangsta bundle
#
#                       developer            publisher overall_reviews  \
# 10768  NetherRealm Studios,QLOC             WB Games        Positive
# 28716                OOTOTGames           OOTOTGames           Mixed
# 28069                  Vionsoft             Vionsoft           Mixed
# 21558                       NaN                  NaN     <10 reviews
# 30148                       NaN                  NaN     <10 reviews
# 48777       Individual Software  Individual Software     <10 reviews
# 33266          CAPCOM Co., Ltd.     CAPCOM Co., Ltd.     <10 reviews
# 20614                       NaN                  NaN     <10 reviews
# 59525          Whitepot Studios     Whitepot Studios   Very Positive
# 31118                       NaN                  NaN     <10 reviews
#
#                                                     tags      ram    year  \
# 10768                                           [Action]     4 GB  2017.0
# 28716              [Adventure, Indie, Retro, Platformer]     1 GB  2017.0
# 28069                    [Strategy, Indie, City Builder]     4 GB  2017.0
# 21558                                          [No Tags]  Unknown     NaN
# 30148                                          [No Tags]  Unknown     NaN
# 48777  [Casual, Education, Software Training, Relaxin...  Unknown  2020.0
# 33266             [Action, RPG, Co-op, Action RPG, JRPG]     8 GB  2022.0
# 20614                                          [No Tags]  Unknown     NaN
# 59525  [Free to Play, Stealth, Indie, Action, Short, ...     4 GB  2020.0
# 31118                                          [No Tags]  Unknown     NaN
#
#       month  user_rating  total_review  supported_language     price  \
# 10768   Nov         93.0          15.0                 8.0   48999.0
# 28716   Apr         68.0          22.0                 1.0   45999.0
# 28069   Nov         66.0          24.0                 2.0   82999.0
# 21558  None          NaN           NaN                 NaN  161098.0
# 30148  None          NaN           NaN                 NaN  174990.0
# 48777   Aug          NaN           NaN                 1.0   32999.0
# 33266   Jan          NaN           NaN                13.0   21999.0
# 20614  None          NaN           NaN                 NaN  161098.0
# 59525   Dec         95.0          85.0                 6.0       0.0
# 31118  None          NaN           NaN                 NaN  185994.0
#
#        pegi_rated  windows  mac  linux  VR
# 10768           1        1    0      0   0
# 28716           0        1    1      0   0
# 28069           0        1    0      0   0
# 21558           0        1    0      0   0
# 30148           0        1    0      0   0
# 48777           0        1    0      0   0
# 33266           1        1    0      0   0
# 20614           0        1    0      0   0
# 59525           0        1    0      0   0
# 31118           0        1    0      0   0

# %%
def to_1D(series): #
 return pd.Series([x for _list in series for x in _list])

# %% [markdown]
# #### reformat and remap `developer`

# %%
df_dev = df_tags.copy()
df_dev.loc[df_dev['developer'].isna()==True,'developer'] = 'Unknown'
df_dev['developer'] = df_dev['developer'].str.split(',')
#df_tags['tags'] = df_tags['tags'].replace(',', '","')
#df_tags['tags'] = '["' + df_tags['tags'] + '"]'
df_dev.sample(10)
# Out:
#                                    title                        developer  \
# 47531                   Fateholder Quest           [Brewsterland Studios]
# 43440    2033: Das Erschwachen der Macht                            [LOT]
# 33324   RPG Maker MZ - FES Resource Pack  [Gotcha Gotcha Games, KADOKAWA]
# 65122  Devil May Cry 5 - Sweet Surrender              [CAPCOM Co.,  Ltd.]
# 42173                     Bounty Hunters        [WhiteSquare Game Studio]
# 51352                 New Supper Banana!                        [Pikku-a]
# 49212                      Koi Solitaire                     [Puzzle Lab]
# 50411          RPG Maker MV - Zonderland                 [Intelligentsia]
# 15114                     Painters Guild                   [Lucas Molina]
# 17011  Robert: Space Stories and Battles                         [Dnovel]
#
#                            publisher overall_reviews  \
# 47531           Brewsterland Studios     <10 reviews
# 43440  Zweitausendeins GmbH & Co. KG     <10 reviews
# 33324                         Degica     <10 reviews
# 65122               CAPCOM Co., Ltd.        Positive
# 42173        WhiteSquare Game Studio     <10 reviews
# 51352                        Pikku-a     <10 reviews
# 49212                 Dikobraz Games     <10 reviews
# 50411                         Degica     <10 reviews
# 15114                   Lucas Molina           Mixed
# 17011                         Dnovel        Positive
#
#                                                     tags      ram    year  \
# 47531  [RPG, Party-Based RPG, JRPG, 3D, Comedy, Fanta...     2 GB  2020.0
# 43440  [Adventure, Interactive Fiction, Visual Novel,...     4 GB  2021.0
# 33324       [RPG, Web Publishing, Design & Illustration]  Unknown  2020.0
# 65122                          [Action, Nudity, Violent]     8 GB  2019.0
# 42173  [Action, Shooter, Arena Shooter, Third-Person ...     8 GB  2022.0
# 51352  [Adventure, Platformer, Funny, Indie, Hand-dra...     1 GB  2021.0
# 49212                                    [Casual, Indie]     1 GB  2018.0
# 50411            [Design & Illustration, Web Publishing]  <128 MB  2018.0
# 15114  [Simulation, Indie, Casual, Strategy, Manageme...     1 GB  2015.0
# 17011  [Casual, Adventure, RPG, Arcade, Visual Novel,...     1 GB  2022.0
#
#       month  user_rating  total_review  supported_language     price  \
# 47531   Aug          NaN           NaN                 1.0   17499.0
# 43440   Sep          NaN           NaN                 2.0   82999.0
# 33324   Sep          NaN           NaN                 2.0  139999.0
# 65122   Mar         92.0          27.0                12.0   29999.0
# 42173   Jan          NaN           NaN                 1.0   39999.0
# 51352   Dec          NaN           NaN                 3.0   32999.0
# 49212   Sep          NaN           NaN                 1.0   59999.0
# 50411   Jul          NaN           NaN                12.0   59999.0
# 15114   Sep         64.0         310.0                 1.0   89999.0
# 17011   Mar        100.0          14.0                 1.0   17499.0
#
#        pegi_rated  windows  mac  linux  VR
# 47531           0        1    0      0   0
# 43440           0        1    0      0   0
# 33324           0        1    1      0   0
# 65122           1        1    0      0   0
# 42173           0        1    1      0   0
# 51352           0        1    0      0   0
# 49212           0        1    0      0   0
# 50411           0        1    1      1   0
# 15114           0        1    0      0   0
# 17011           0        1    0      0   0

# %%
to_1D(df_dev['developer']).value_counts().head(100)
# Out:
# Unknown                    5214
# Ubisoft - San Francisco    1166
#  LTD.                      1137
#  LLC                       1108
# KOEI TECMO GAMES CO.        974
#                            ...
# TK.Projects                  50
# Techland                     50
# Orange_Juice                 49
# AMAX Interactive             49
# Harmonix Music Systems       49
# Length: 100, dtype: int64

# %% [markdown]
# #### reformat and remap `publisher`

# %%
df_pub = df_dev.copy()
df_pub.loc[df_pub['publisher'].isna()==True,'publisher'] = 'Unknown'
df_pub['publisher'] = df_pub['publisher'].str.split(',')
df_pub.sample(10)
# Out:
#                                                    title  \
# 68208                                          Ironsight
# 37394  RTK13WPK - Watercolor Painting Style Officer C...
# 47994  Rocksmith® 2014 Edition – Remastered – Raspber...
# 22141                                          Gun Witch
# 58579                     Grotesque Tactics: Evil Heroes
# 34056                                      Fimbul Winter
# 32221                                      DUMB Infernal
# 3692   Higurashi When They Cry Hou - Ch.6 Tsumihoroboshi
# 18224                                    Race Race Racer
# 395                     ARK: Extinction - Expansion Pack
#
#                                                developer  \
# 68208                                [WipleGames Inc., ]
# 37394                      [KOEI TECMO GAMES CO.,  LTD.]
# 47994                          [Ubisoft - San Francisco]
# 22141                                      [AGM Studios]
# 58579                                    [Silent Dreams]
# 34056                                    [Success Games]
# 32221                                       [Beem Media]
# 3692                                    [07th Expansion]
# 18224  [Enaayah Software Development and Services Pri...
# 395    [Studio Wildcard, Instinct Games, Efecto Studi...
#
#                                                publisher  overall_reviews  \
# 68208                                [WipleGames Inc., ]            Mixed
# 37394                      [KOEI TECMO GAMES CO.,  LTD.]      <10 reviews
# 47994                                          [Unknown]      <10 reviews
# 22141                                      [AGM Studios]    Very Positive
# 58579                                           [Headup]            Mixed
# 34056                                    [Success Games]  Mostly Negative
# 32221                                       [Beem Media]            Mixed
# 3692                                        [MangaGamer]    Very Positive
# 18224  [Enaayah Software Development and Services Pri...         Positive
# 395                   [Snail Games USA, Studio Wildcard]    Very Positive
#
#                                                     tags      ram    year  \
# 68208  [Free to Play, Action, FPS, Multiplayer, Shoot...     6 GB  2019.0
# 37394                                       [Simulation]     1 GB  2017.0
# 47994                               [Casual, Simulation]     2 GB  2017.0
# 22141  [Adventure, RPG, Platformer, Action RPG, Shoot...     1 GB  2020.0
# 58579  [RPG, Strategy, Indie, Turn-Based, Parody , Ta...     1 GB  2010.0
# 34056  [Action, Adventure, Simulation, Strategy, Sing...     2 GB  2021.0
# 32221       [Action, Indie, FPS, Arcade, Pixel Graphics]  Unknown  2020.0
# 3692   [Visual Novel, Adventure, Horror, Anime, Myste...     1 GB  2018.0
# 18224  [Racing, Casual, Relaxing, Comedy, Great Sound...     2 GB  2019.0
# 395    [Adventure, Action, Massively Multiplayer, Sur...     8 GB  2018.0
#
#       month  user_rating  total_review  supported_language    price  \
# 68208   Jun         68.0         566.0                14.0      0.0
# 37394   Jun          NaN           NaN                 5.0  35999.0
# 47994   May          NaN           NaN                 6.0  45000.0
# 22141   Dec         91.0         213.0                 1.0      0.0
# 58579   Oct         60.0         285.0                 2.0  89999.0
# 34056   May         20.0          10.0                 5.0   8499.0
# 32221   Jan         65.0          23.0                 1.0      0.0
# 3692    Jun         98.0         334.0                 2.0  59999.0
# 18224   Dec         84.0          26.0                 1.0   8499.0
# 395     Nov         86.0          15.0                21.0      NaN
#
#        pegi_rated  windows  mac  linux  VR
# 68208           0        1    0      0   0
# 37394           1        1    0      0   0
# 47994           1        1    1      0   0
# 22141           0        1    0      0   0
# 58579           0        1    0      0   0
# 34056           0        1    0      0   0
# 32221           0        1    0      0   0
# 3692            0        1    1      1   0
# 18224           0        1    1      1   0
# 395             1        1    1      1   0

# %%
to_1D(df_pub['publisher']).value_counts().head(60)
# Out:
# Unknown                       10180
# Degica                         1078
#  LTD.                           906
#  Inc.                           862
# KOEI TECMO GAMES CO.            788
#  Ltd.                           678
# Dovetail Games - Trains         514
# CAPCOM Co.                      466
# Paradox Interactive             425
# Big Fish Games                  380
# BANDAI NAMCO Entertainment      380
# SEGA                            379
# Square Enix                     375
# Electronic Arts                 325
# D3 PUBLISHER                    324
# Ubisoft                         319
#  LLC                            308
# XSEED Games                     289
# Marvelous USA                   283
# THQ Nordic                      281
# Feral Interactive (Mac)         269
# 2K                              228
# Dovetail Games - Flight         228
# Slitherine Ltd.                 224
# Idea Factory International      212
# Feral Interactive (Linux)       204
# 8floor                          197
# NIS America                     188
# Sekai Project                   188
# Dovetail Games                  177
# Aerosoft GmbH                   166
# PQube                           161
# Rebellion                       159
# Xbox Game Studios               158
# PLAYISM                         156
# Devolver Digital                148
# Focus Home Interactive          147
# Capcom                          147
# Choice of Games                 146
# Nacon                           144
# 1C Entertainment                138
# Strategy First                  136
# Plug In Digital                 135
# HH-Games                        133
# Milestone S.r.l.                132
# 505 Games                       120
# Activision                      115
# Deep Silver                     114
# N3V Games                       109
# Alawar Entertainment            108
# SCS Software                    107
# Bethesda Softworks              107
# tinyBuild                       106
# Daedalic Entertainment          105
# Ziggurat                        105
# Aspyr (Mac)                     100
# PlayWay S.A.                    100
# Nightdive Studios                99
# Kalypso Media Digital            98
# Gotcha Gotcha Games              97
# dtype: int64

# %% [markdown]
# ## data understanding

# %%
df_final = df_pub.copy()
df_final.sample(5)
# Out:
#                            title          developer  \
# 55850  Australian Football Coach  [Statto Software]
# 3785              Geometry Arena        [011 Games]
# 1259         Lethal League Blaze     [Team Reptile]
# 6157                  Mutropolis    [Pirita Studio]
# 19099                    100 nya          [.M.Y.W.]
#
#                               publisher  overall_reviews  \
# 55850                 [Statto Software]  Mostly Negative
# 3785                        [011 Games]    Very Positive
# 1259                     [Team Reptile]    Very Positive
# 6157   [Application Systems Heidelberg]    Very Positive
# 19099                         [.M.Y.W.]         Positive
#
#                                                     tags   ram    year month  \
# 55850  [Strategy, Indie, Simulation, Sports, Football...  1 GB  2017.0   Sep
# 3785   [Roguelite, Bullet Hell, Minimalist, Replay Va...  8 GB  2021.0   Jun
# 1259   [Action, Indie, Great Soundtrack, 2D Fighter, ...  4 GB  2018.0   Oct
# 6157   [Indie, Detective, Adventure, Point & Click, M...  4 GB  2021.0   Feb
# 19099                          [Indie, Strategy, Puzzle]  1 GB  2016.0   Nov
#
#        user_rating  total_review  supported_language     price  pegi_rated  \
# 55850         30.0          10.0                 1.0  108999.0           0
# 3785          96.0          26.0                 2.0   48999.0           0
# 1259         100.0          32.0                10.0  108999.0           0
# 6157          91.0          86.0                10.0  108999.0           0
# 19099         91.0          23.0                19.0   69999.0           0
#
#        windows  mac  linux  VR
# 55850        1    0      0   0
# 3785         1    1      0   0
# 1259         1    1      1   0
# 6157         1    1      1   0
# 19099        1    0      0   0

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64887 entries, 0 to 68467
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               64887 non-null  object
#  1   developer           64887 non-null  object
#  2   publisher           64887 non-null  object
#  3   overall_reviews     64887 non-null  object
#  4   tags                64887 non-null  object
#  5   ram                 64887 non-null  object
#  6   year                59907 non-null  float64
#  7   month               59903 non-null  object
#  8   user_rating         38188 non-null  float64
#  9   total_review        38188 non-null  float64
#  10  supported_language  57750 non-null  float64
#  11  price               64366 non-null  float64
#  12  pegi_rated          64887 non-null  int32
#  13  windows             64887 non-null  int32
#  14  mac                 64887 non-null  int32
#  15  linux               64887 non-null  int32
#  16  VR                  64887 non-null  int32
# dtypes: float64(5), int32(5), object(7)
# memory usage: 9.7+ MB

# %%
df_final.describe()
# Out:
#                year   user_rating   total_review  supported_language  \
# count  59907.000000  38188.000000   38188.000000        57750.000000
# mean    2018.223396     76.416963     218.957971            4.774130
# std        2.773410     18.492328    4440.137845            5.349063
# min     1997.000000      0.000000      10.000000            1.000000
# 25%     2017.000000     66.000000      18.000000            1.000000
# 50%     2019.000000     80.000000      40.000000            2.000000
# 75%     2020.000000     91.000000     122.000000            7.000000
# max     2077.000000    100.000000  558563.000000           29.000000
#
#               price    pegi_rated       windows           mac         linux  \
# count  6.436600e+04  64887.000000  64887.000000  64887.000000  64887.000000
# mean   8.363383e+04      0.201181      0.965232      0.283632      0.167707
# std    1.588174e+05      0.400886      0.183193      0.450764      0.373609
# min    0.000000e+00      0.000000      0.000000      0.000000      0.000000
# 25%    2.499900e+04      0.000000      1.000000      0.000000      0.000000
# 50%    5.299900e+04      0.000000      1.000000      0.000000      0.000000
# 75%    9.599900e+04      0.000000      1.000000      1.000000      0.000000
# max    8.990155e+06      1.000000      1.000000      1.000000      1.000000
#
#                  VR
# count  64887.000000
# mean       0.009493
# std        0.096971
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df_final[['overall_reviews','ram']].describe()
# Out:
#        overall_reviews    ram
# count            64887  64887
# unique              10     11
# top        <10 reviews   4 GB
# freq             26699  13515

# %% [markdown]
# ## export csv

# %%
df_final.to_csv('for_EDA.csv', index=False)

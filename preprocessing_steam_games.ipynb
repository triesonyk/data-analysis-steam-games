# %% [markdown]
# ## import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# ## load dataset

# %%
raw = pd.read_csv('steam_games.csv')
raw.sample(5)
# Out:
#                                                    title  \
# 21265  東周列萌志 Philosophic Love－原聲帶組合包 OST Bundle（升級包 U...
# 26991                            Treasure Adventure Game
# 52022                                     Slime Research
# 6965                            Svoboda 1945: Liberation
# 9337                                  Super Chibi Knight
#
#                                                      url  \
# 21265  https://store.steampowered.com/bundle/13561/_P...
# 26991  https://store.steampowered.com/app/863940/Trea...
# 52022  https://store.steampowered.com/app/966180/Slim...
# 6965   https://store.steampowered.com/app/1076620/Svo...
# 9337   https://store.steampowered.com/app/283080/Supe...
#
#                                                    image  release_date  \
# 21265  https://cdn.akamai.steamstatic.com/steam/bundl...           NaN
# 26991  https://cdn.akamai.steamstatic.com/steam/apps/...  19 Mar, 2021
# 52022  https://cdn.akamai.steamstatic.com/steam/apps/...   2 Jan, 2019
# 6965   https://cdn.akamai.steamstatic.com/steam/apps/...   3 Aug, 2021
# 9337   https://cdn.akamai.steamstatic.com/steam/apps/...  24 Jun, 2015
#
#                   platforms discount_rate original_price discounted_price  \
# 21265        Windows,Mac OS           NaN     Rp 142 198              NaN
# 26991               Windows           NaN           Free              NaN
# 52022  Windows,Mac OS,Linux           NaN      Rp 39 999              NaN
# 6965   Windows,Mac OS,Linux           NaN      Rp 99 999              NaN
# 9337   Windows,Mac OS,Linux           NaN      Rp 45 999              NaN
#
#            developer                       publisher overall_reviews  \
# 21265            NaN                             NaN             NaN
# 26991    Robit Games                     Robit Games        Positive
# 52022     Schism LLC                      Schism LLC  3 user reviews
# 6965   Charles Games                   Charles Games   Very Positive
# 9337      PestoForce  Armor Games Studios,PestoForce   Very Positive
#
#                                             text_reviews  \
# 21265                                                NaN
# 26991  - 90% of the 20 user reviews for this game are...
# 52022       - Need more user reviews to generate a score
# 6965   - 97% of the 71 user reviews for this game are...
# 9337   - 88% of the 278 user reviews for this game ar...
#
#                                              description  \
# 21265                                                NaN
# 26991  Treasure Adventure Game casts you in the role ...
# 52022                           Slimy Puzzle Platforming
# 6965   Svoboda 1945: Liberation is a unique blend of ...
# 9337   The Kingdom of Oukoku is threatened by the spi...
#
#                                                     tags  \
# 21265                                                NaN
# 26991  Metroidvania,2D Platformer,Action,Puzzle Platf...
# 52022  Physics,2D Platformer,Controller,Level Editor,...
# 6965   Singleplayer,Visual Novel,Emotional,Adventure,...
# 9337   Action,Adventure,Indie,RPG,2D,Action RPG,Singl...
#
#                            processor          ram  \
# 21265                            NaN          NaN
# 26991              1.8 GHz Processor   512 MB RAM
# 52022   SSE2 instruction set support   200 MB RAM
# 6965                         1.6 GHz     8 GB RAM
# 9337                         2.5 GHz     1 GB RAM
#
#                                             graphic_card rating  \
# 21265                                                NaN    NaN
# 26991         3D graphics card compatible with DirectX 7    NaN
# 52022   Graphics card with DX10 (shader model 4.0) ca...    NaN
# 6965                           HD Graphics 530 or better    NaN
# 9337                        Direct X9.0c Compatible Card    NaN
#
#                                                 language  metacriticts
# 21265                                                NaN           NaN
# 26991                                            English           NaN
# 52022                                            English           NaN
# 6965                                English,Czech,German          81.0
# 9337   English,French,Italian,German,Spanish - Spain,...           NaN

# %% [markdown]
# ## data understanding

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68468 entries, 0 to 68467
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             68468 non-null  object
#  1   url               68468 non-null  object
#  2   image             68468 non-null  object
#  3   release_date      62160 non-null  object
#  4   platforms         66194 non-null  object
#  5   discount_rate     5401 non-null   object
#  6   original_price    67795 non-null  object
#  7   discounted_price  5401 non-null   object
#  8   developer         61855 non-null  object
#  9   publisher         56815 non-null  object
#  10  overall_reviews   55479 non-null  object
#  11  text_reviews      55479 non-null  object
#  12  description       40956 non-null  object
#  13  tags              61039 non-null  object
#  14  processor         55299 non-null  object
#  15  ram               55091 non-null  object
#  16  graphic_card      51361 non-null  object
#  17  rating            13428 non-null  object
#  18  language          59912 non-null  object
#  19  metacriticts      1881 non-null   float64
# dtypes: float64(1), object(19)
# memory usage: 10.4+ MB

# %% [markdown]
# Observations:
# - `url`,`image`,`discount_rate`,`discounted_price`,`description` drop
# - `release_date` extract month and year
# - `platfoms`,`developer`,`publisher`,`tags` split
# - `original_price` change data type (extract price)
# - `text_reviews` extract rating (`user_rating`) and total user reviews (`total_reviews`)
# - `language` extract number of language (`language`)
# - `metacriticts` too much missing values, drop

# %%
raw.describe()
# Out:
#        metacriticts
# count   1881.000000
# mean      80.971823
# std        4.458169
# min       75.000000
# 25%       77.000000
# 50%       80.000000
# 75%       84.000000
# max       97.000000

# %%
raw.describe(include='object')
# Out:
#                     title                                                url  \
# count               68468                                              68468
# unique              64887                                              68468
# top     Game + Soundtrack  https://store.steampowered.com/app/730/Counter...
# freq                   13                                                  1
#
#                                                     image  release_date  \
# count                                               68468         62160
# unique                                              65033          3894
# top     https://cdn.akamai.steamstatic.com/steam/apps/...  14 Oct, 2020
# freq                                                    6           146
#
#        platforms discount_rate original_price discounted_price  \
# count      66194          5401          67795             5401
# unique        12            89           4591             1500
# top      Windows          -50%      Rp 69 999         Rp 4 249
# freq       44961          1006           5108              329
#
#                       developer publisher overall_reviews  \
# count                     61855     56815           55479
# unique                    24765     20134              18
# top     Ubisoft - San Francisco    Degica   Very Positive
# freq                       1167      1049           11078
#
#                                         text_reviews  \
# count                                          55479
# unique                                         13440
# top     - Need more user reviews to generate a score
# freq                                           15169
#
#                                     description    tags  \
# count                                     40956   61039
# unique                                    39011   40137
# top     Minimal physical puzzle with explosions  Action
# freq                                         15    1715
#
#                                                 processor        ram  \
# count                                               55299      55091
# unique                                              12423        859
# top     2.66 GHz Intel Core2 Duo E6750 or 2.8 GHz AMD ...   4 GB RAM
# freq                                                  801      13411
#
#                                              graphic_card            rating  \
# count                                               51361             13428
# unique                                              14567                 1
# top     256 MB DirectX 9 / NVIDIA® GeForce® 8600 GT or...  Rating for: PEGI
# freq                                                 1167             13428
#
#        language
# count     59912
# unique     7879
# top     English
# freq      24115

# %% [markdown]
# observations:
# - `rating` data is wrong, consider drop or rescrape data
# - `tags` too much unique value, consider to create new columns tag that has been aggregated

# %% [markdown]
# ## data preprocessing (format)

# %% [markdown]
# ### drop duplicates and uninformative columns

# %%
df_drop = raw.copy()
df_drop.drop_duplicates(subset='title',inplace=True)
df_drop['title'].duplicated().sum()
# Out:
# 0

# %%
drop = ['url','image','discount_rate','discounted_price','description','metacriticts','processor','graphic_card'] #these variables unable to show any kind of valuable information that can be used for current analysis and machine learning model, consider to be used for other analysis
df_drop = df_drop.drop(labels=drop,axis=1)
df_drop.sample(10)
# Out:
#                                         title  release_date       platforms  \
# 12737              Injustice™ 2 - Enchantress  16 Jan, 2018         Windows
# 31964                                EXCHANGE  12 Oct, 2018         Windows
# 58937             Rogue Port - Blue Nightmare  31 Mar, 2017         Windows
# 63034  Train Simulator: DB BR 361 Loco Add-On  18 Dec, 2015         Windows
# 2662         PAYDAY 2: Gunslinger Weapon Pack  11 Nov, 2020   Windows,Linux
# 20887                   Farm and Train Bundle           NaN         Windows
# 61860                  CHUCHEL Cherry Edition           NaN  Windows,Mac OS
# 5925                           Rags to Dishes  11 Nov, 2020         Windows
# 31486                                Artizens   5 Mar, 2015         Windows
# 27863                              Simple Man  12 Mar, 2018         Windows
#
#       original_price                        developer  \
# 12737      Rp 48 999         NetherRealm Studios,QLOC
# 31964      Rp 39 999           Self Destruction Games
# 58937       Rp 8 500              Volens Nolens Games
# 63034     Rp 135 999                   Dovetail Games
# 2662       Rp 25 999  OVERKILL - a Starbreeze Studio.
# 20887     Rp 215 998                              NaN
# 61860      Rp 94 998                              NaN
# 5925      Rp 108 999                           Novity
# 31486            NaN                   Artizens, Inc.
# 27863      Rp 17 499                              CSM
#
#                      publisher  overall_reviews  \
# 12737                      NaN         Positive
# 31964   Self Destruction Games            Mixed
# 58937      Volens Nolens Games            Mixed
# 63034  Dovetail Games - Trains         Positive
# 2662                       NaN  Mostly Positive
# 20887                      NaN              NaN
# 61860                      NaN              NaN
# 5925                    Novity    Very Positive
# 31486           Artizens, Inc.            Mixed
# 27863                   W.T.B.            Mixed
#
#                                             text_reviews  \
# 12737  - 84% of the 13 user reviews for this game are...
# 31964  - 66% of the 18 user reviews for this game are...
# 58937  - 64% of the 14 user reviews for this game are...
# 63034  - 93% of the 15 user reviews for this game are...
# 2662   - 78% of the 123 user reviews for this game ar...
# 20887                                                NaN
# 61860                                                NaN
# 5925   - 97% of the 102 user reviews for this game ar...
# 31486  - 48% of the 31 user reviews for this game are...
# 27863  - 47% of the 17 user reviews for this game are...
#
#                                                     tags          ram  \
# 12737                                             Action     4 GB RAM
# 31964  Indie,Action,Massively Multiplayer,Casual,Earl...     2 GB RAM
# 58937  Action,Adventure,RPG,Indie,Pixel Graphics,RPGM...          NaN
# 63034                                         Simulation     2 GB RAM
# 2662                             RPG,Action,Gore,Violent     4 GB RAM
# 20887                                                NaN          NaN
# 61860                                                NaN          NaN
# 5925   Simulation,Casual,VR,Singleplayer,First-Person...     8 GB RAM
# 31486                      Early Access,Action,RPG,Indie     2 GB RAM
# 27863                         Action,Adventure,RPG,Indie   512 MB RAM
#
#                  rating                                           language
# 12737  Rating for: PEGI  English,French,Italian,German,Spanish - Spain,...
# 31964               NaN                                    English,Turkish
# 58937               NaN                                            English
# 63034  Rating for: PEGI                              English,French,German
# 2662   Rating for: PEGI  English,German,French,Italian,Spanish - Spain,...
# 20887               NaN                                                NaN
# 61860               NaN                                                NaN
# 5925   Rating for: PEGI                                            English
# 31486               NaN                                            English
# 27863               NaN                                    English,Russian

# %% [markdown]
# ### data extraction and formatting

# %% [markdown]
# #### extract `month` and `year`

# %%
#define function to extract year
def extract_year(x):
    year = None
    if type(x) == list:
        for i in x:
            if len(i) == 4:
                year = i
                return year
            else: 
                year = None
        return year
    else:
        year = x
    return year

# %%
#df_drop[['date','month','year']] = df_drop['release_date'].str.split(' ', n=2 , expand=True)
df_extract = df_drop.copy()
month = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
#df_extract['year'] = df_extract['release_date'].str[-4:].apply(pd.to_numeric, errors=('coerce')) 
df_extract['year'] = df_extract['release_date'].str.findall('(\d+)').apply(lambda x: extract_year(x)).astype(float)
df_extract['month'] = df_extract['release_date'].str.findall("[a-zA-Z]+").str[0]
df_extract['month'] = df_extract['month'].replace(['August','June'],['Aug','Jun'])
df_extract.loc[~df_extract['month'].isin(month),'month'] = None
df_extract = df_extract.drop('release_date', axis=1) #drop release date
df_extract.sample(5)
# Out:
#                                                    title  \
# 43611                                            GunHero
# 61766                                          Scoregasm
# 32815       Total War: SHOGUN 2 - Dragon War Battle Pack
# 28993                                         Magic gems
# 22197  The Witcher 3: Wild Hunt - Nilfgaardian Armor Set
#
#                   platforms original_price  \
# 43611         Windows,Linux      Rp 59 999
# 61766        Windows,Mac OS      Rp 45 999
# 32815  Windows,Mac OS,Linux      Rp 53 999
# 28993               Windows      Rp 83 999
# 22197               Windows           Free
#
#                                                developer  \
# 43611                                 Olli-Samuli Lehmus
# 61766                                          RC Knight
# 32815  The Creative Assembly,Feral Interactive (Mac),...
# 28993                                             Feanus
# 22197                                     CD PROJEKT RED
#
#                                                publisher overall_reviews  \
# 43611                                 Olli-Samuli Lehmus  4 user reviews
# 61766                                    Charlie's Games   Very Positive
# 32815  SEGA,Feral Interactive (Mac),Feral Interactive...           Mixed
# 28993                                      kovalevviktor           Mixed
# 22197                                                NaN   Very Positive
#
#                                             text_reviews  \
# 43611       - Need more user reviews to generate a score
# 61766  - 83% of the 79 user reviews for this game are...
# 32815  - 62% of the 101 user reviews for this game ar...
# 28993  - 69% of the 13 user reviews for this game are...
# 22197  - 92% of the 328 user reviews for this game ar...
#
#                                                     tags  \
# 43611                            Action,Indie,Platformer
# 61766  Action,Indie,Twin Stick Shooter,Bullet Hell,Sc...
# 32815                                           Strategy
# 28993  Simulation,2D,Runner,Colorful,Pixel Graphics,F...
# 22197                                   Free to Play,RPG
#
#                                               ram            rating  \
# 43611                                    1 GB RAM               NaN
# 61766           512mb\n\t\t\t\t\t\t\t\t\t\t\t\t\t               NaN
# 32815   1GB RAM (XP), 2GB RAM (Vista / Windows7)   Rating for: PEGI
# 28993                                 1024 MB RAM               NaN
# 22197                                    6 GB RAM  Rating for: PEGI
#
#                                                 language    year month
# 43611                                    English,Finnish  2017.0   Apr
# 61766                                            English  2012.0   Feb
# 32815  English,Czech,French,German,Italian,Polish,Rus...  2012.0   May
# 28993                                            English  2021.0   Jul
# 22197  English,French,Italian,German,Spanish - Spain,...  2015.0   Jun

# %% [markdown]
# #### extract `user_rating` and `total_reviews`

# %%
df_extract_2 = df_extract.copy()
df_extract_2['text_reviews'] = df_extract_2['text_reviews'].str.replace(',','')
df_extract_2['user_rating'] = df_extract_2['text_reviews'].str.findall('(\d+)').str[0].astype(float)
df_extract_2['total_review'] = df_extract_2['text_reviews'].str.findall('(\d+)').str[1].astype(float)
df_extract_2 = df_extract_2.drop('text_reviews',axis=1)
df_extract_2.sample(5)
# Out:
#                                      title       platforms original_price  \
# 42134    V-Skin Webcam Hand Expansion Pack  Windows,Mac OS     Rp 424 999
# 63195                     Neko Hacker Plus         Windows      Rp 24 999
# 54756                Midnight's Blessing 2         Windows      Rp 69 999
# 51727  Tennis World Tour - Caroline Garcia         Windows      Rp 24 999
# 41162        Watch_Dogs® 2 - EliteSec Pack         Windows      Rp 70 000
#
#                          developer                    publisher  \
# 42134  Q.B.Q.F MULTIMEDIA CO.,LTD.  Q.B.Q.F MULTIMEDIA CO.,LTD.
# 63195                  Axyos Games                  Axyos Games
# 54756              Warfare Studios              Warfare Studios
# 51727                   Breakpoint                        Nacon
# 41162                      Ubisoft                          NaN
#
#       overall_reviews                                               tags  \
# 42134             NaN  Video Production,Audio Production,Web Publishi...
# 63195        Positive  Nudity,NSFW,Cute,Puzzle,Anime,Casual,Sexual Co...
# 54756  6 user reviews  Adventure,Indie,Casual,Simulation,RPG,Strategy...
# 51727             NaN                                             Sports
# 41162  8 user reviews                                   Action,Adventure
#
#                ram            rating  \
# 42134     4 GB RAM               NaN
# 63195     4 GB RAM               NaN
# 54756   128 MB RAM               NaN
# 51727          NaN  Rating for: PEGI
# 41162     6 GB RAM               NaN
#
#                                                 language    year month  \
# 42134  English,Japanese,Simplified Chinese,Traditiona...  2022.0   Feb
# 63195                                            English  2021.0   Sep
# 54756                                            English  2017.0   Jan
# 51727  English,French,Italian,German,Spanish - Spain,...  2020.0   Apr
# 41162  English,French,Italian,German,Spanish - Spain,...  2016.0   Dec
#
#        user_rating  total_review
# 42134          NaN           NaN
# 63195         80.0          26.0
# 54756          NaN           NaN
# 51727          NaN           NaN
# 41162          NaN           NaN

# %% [markdown]
# #### extract `supported_language`

# %%
df_extract_3 = df_extract_2.copy()
df_extract_3['supported_language'] = df_extract_3['language'].str.split(',').apply(lambda x: len(x) if type(x) == list else x)
#df_extract_3['english_language'] = df_extract_3['language'].str.lower().str.contains('english')
df_extract_3 = df_extract_3.drop('language',axis=1)
df_extract_3.sample(5)
# Out:
#                                                    title       platforms  \
# 35159  Nobunaga's Ambition: Taishi - シナリオ「長篠の戦い」/Scen...         Windows
# 52778  The Legend of Heroes: Trails of Cold Steel III...         Windows
# 57565    Die With Glory — Point and Click Adventure Game  Windows,Mac OS
# 39350  TS Marketplace: Amtrak E8 Scenario Pack 01 Add-On         Windows
# 8728   ONE PIECE: PIRATE WARRIORS 4 Whole Cake Island...         Windows
#
#       original_price                                 developer  \
# 35159      Rp 37 000                KOEI TECMO GAMES CO., LTD.
# 52778       Rp 8 499  Nihon Falcom,Engine Software BV,PH3 GmbH
# 57565      Rp 48 999                                    Castle
# 39350      Rp 69 999                     High Iron Simulations
# 8728      Rp 119 000                                Koei Tecmo
#
#                         publisher overall_reviews  \
# 35159  KOEI TECMO GAMES CO., LTD.  3 user reviews
# 52778           NIS America, Inc.  1 user reviews
# 57565                 Veslo Games           Mixed
# 39350     Dovetail Games - Trains  1 user reviews
# 8728   BANDAI NAMCO Entertainment        Positive
#
#                                                     tags          ram  \
# 35159                                         Simulation     2 GB RAM
# 52778                                                RPG          NaN
# 57565  Adventure,Action,Indie,Point & Click,Funny,2D,...   512 MB RAM
# 39350                                         Simulation     4 GB RAM
# 8728                                              Action     8 GB RAM
#
#                  rating    year month  user_rating  total_review  \
# 35159  Rating for: PEGI  2018.0   Jun          NaN           NaN
# 52778               NaN  2020.0   Mar          NaN           NaN
# 57565               NaN  2017.0   May         46.0          32.0
# 39350  Rating for: PEGI  2018.0   Jun          NaN           NaN
# 8728   Rating for: PEGI  2020.0   Jul         83.0          30.0
#
#        supported_language
# 35159                 3.0
# 52778                 3.0
# 57565                 2.0
# 39350                 1.0
# 8728                 13.0

# %% [markdown]
# #### extract `price`

# %%
df_price = df_extract_3.copy()
df_price['price'] = df_price['original_price'].str.lower().str.strip('rp ').str.replace(' ','').astype(int,errors='ignore')
df_price.loc[df_price['price'].str.contains('free|demo|season|third|now',na=False),'price'] = 0
df_price['price'] = df_price['price'].astype(float)
df_price = df_price.drop('original_price',axis=1)
df_price.sample(5)
# Out:
#                                   title             platforms  \
# 4029                             Owlboy  Windows,Mac OS,Linux
# 8299                    Secret Agent HD         Windows,Linux
# 56448        Animalia New African Skins               Windows
# 60866                    Output Pasture               Windows
# 20069  Word Wonders: The Tower of Babel               Windows
#
#                    developer                      publisher  overall_reviews  \
# 4029            D-Pad Studio                   D-Pad Studio  Mostly Positive
# 8299        Emberheart Games           Apogee Entertainment    Very Positive
# 56448     High Brazil Studio             High Brazil Studio   4 user reviews
# 60866          DuskDogStudio  DuskDogStudio,HeartBeat Games         Positive
# 20069  Chimera Entertainment                GAMES in FLAMES         Positive
#
#                                                     tags          ram  \
# 4029   Pixel Graphics,Adventure,Indie,Great Soundtrac...     1 GB RAM
# 8299   Action,Adventure,Puzzle Platformer,Platformer,...   512 MB RAM
# 56448  Action,Adventure,Indie,Massively Multiplayer,S...          NaN
# 60866   Strategy,Indie,Casual,Tower Defense,2D,Roguelike     4 GB RAM
# 20069                                   Casual,Word Game     1 GB RAM
#
#                  rating    year month  user_rating  total_review  \
# 4029   Rating for: PEGI  2016.0   Nov         75.0          12.0
# 8299                NaN  2021.0   Jun         98.0          79.0
# 56448               NaN  2022.0   Feb          NaN           NaN
# 60866               NaN  2020.0   Mar         88.0          45.0
# 20069               NaN  2015.0   May        100.0          15.0
#
#        supported_language     price
# 4029                 13.0  169999.0
# 8299                  1.0   59999.0
# 56448                 1.0   69999.0
# 60866                 5.0   64999.0
# 20069                 1.0   32999.0

# %% [markdown]
# #### extract `rated_by_pegi`

# %%
df_pegi = df_price.copy()
df_pegi['pegi_rated'] = np.where(df_pegi['rating']=='Rating for: PEGI', 1, 0)
df_pegi = df_pegi.drop('rating',axis=1)
df_pegi.sample(5)
# Out:
#                                                    title platforms  \
# 9400                         "ONEECHANBARA WORLD" BUNDLE   Windows
# 57006                                    Gauntlet of IRE   Windows
# 68424                               GUILTY GEAR -STRIVE-   Windows
# 5375   Assassin’s Creed Unity Revolutionary Armaments...   Windows
# 12684     Train Simulator: Union Pacific U50 Loco Add-On   Windows
#
#                  developer                publisher  overall_reviews  \
# 9400                   NaN                      NaN              NaN
# 57006      KillerPokeGames          KillerPokeGames  Mostly Positive
# 68424     Arc System Works         Arc System Works    Very Positive
# 5375               Ubisoft                  Ubisoft  Mostly Negative
# 12684  Digital Train Model  Dovetail Games - Trains            Mixed
#
#                                                     tags        ram    year  \
# 9400                                                 NaN        NaN     NaN
# 57006  Casual,Action,Indie,Difficult,Isometric,Side S...   4 GB RAM  2017.0
# 68424  2D Fighter,Fighting,Anime,2.5D,PvP,Arcade,Grea...   4 GB RAM  2021.0
# 5375                                    Action,Adventure        NaN  2014.0
# 12684                                         Simulation   4 GB RAM  2018.0
#
#       month  user_rating  total_review  supported_language      price  \
# 9400   None          NaN           NaN                 NaN  1338998.0
# 57006   Dec         76.0         158.0                 1.0        0.0
# 68424   Jun         93.0         527.0                 9.0   749000.0
# 5375    Nov         30.0          13.0                14.0    30000.0
# 12684   May         63.0          11.0                 1.0   108999.0
#
#        pegi_rated
# 9400            0
# 57006           1
# 68424           0
# 5375            1
# 12684           1

# %% [markdown]
# #### extract `windows`, `mac`, and `linux`

# %%
df_platform = df_pegi.copy()
df_platform['windows'] = np.where(df_platform['platforms'].str.contains('Windows',na=False), 1, 0)
df_platform['mac'] = np.where(df_platform['platforms'].str.contains('Mac OS',na=False), 1, 0)
df_platform['linux'] = np.where(df_platform['platforms'].str.contains('Linux',na=False), 1, 0)
df_platform['VR'] = np.where(df_platform['platforms'].str.contains('VR Supported',na=False), 1, 0)
df_platform = df_platform.drop('platforms',axis=1)
df_platform.sample(10)
# Out:
#                                                    title  \
# 61448                   宥蘿的奇幻冒險 YURO'S FANTASY ADVENTURE
# 55535  MELTY BLOOD: TYPE LUMINA - Round Announcements...
# 27392                            Runaway Express Mystery
# 10784                  Fluffy Store - Listening with you
# 24514                                      Armored Train
# 38983  Heroes & Generals - GE Soldier Pack: Medium Ta...
# 9523   Tangledeep Complete (Includes Both Expansions ...
# 44695                                            JS Page
# 6677               Borderlands 2: Gunzerker Madness Pack
# 53416                                     Colorless Life
#
#                                                developer  \
# 61448                                戴永翔(Dai Yong Xiang)
# 55535  FRENCH-BREAD,TYPE-MOON,DELiGHTWORKS Inc.,TAMSO...
# 27392                                       Icarus Games
# 10784                                           AsicxArt
# 24514                                             NORSKA
# 38983                                       TLM Partners
# 9523                                                 NaN
# 44695                                            Geargom
# 6677          Gearbox Software,Aspyr (Mac),Aspyr (Linux)
# 53416                                              HIPIX
#
#                           publisher  overall_reviews  \
# 61448           戴永翔(Dai Yong Xiang)         Positive
# 55535             DELiGHTWORKS Inc.   3 user reviews
# 27392                      Libredia            Mixed
# 10784                    SakuraGame         Positive
# 24514                        NORSKA            Mixed
# 38983                  TLM Partners   4 user reviews
# 9523                            NaN              NaN
# 44695                       Geargom              NaN
# 6677   2K,Aspyr (Mac),Aspyr (Linux)  Mostly Positive
# 53416                         HIPIX   9 user reviews
#
#                                                     tags  \
# 61448  RPG,Casual,Anime,JRPG,Cute,Adventure,Funny,Act...
# 55535  Action,PvP,Multiplayer,2D,Pixel Graphics,Vampi...
# 27392                 Casual,Hidden Object,Point & Click
# 10784                         Adventure,RPG,Indie,Casual
# 24514  Strategy,Adventure,Indie,RPG,Simulation,Pixel ...
# 38983  Strategy,Action,Free to Play,Massively Multipl...
# 9523                                                 NaN
# 44695  Utilities,Education,Web Publishing,Software Tr...
# 6677                                          Action,RPG
# 53416  Casual,Adventure,Indie,Action,Simulation,Horro...
#
#                           ram    year month  user_rating  total_review  \
# 61448                8 GB RAM  2020.0   Nov        100.0          18.0
# 55535                4 GB RAM  2021.0   Sep          NaN           NaN
# 27392             1024 MB RAM  2014.0   Sep         68.0          22.0
# 10784                1 GB RAM  2019.0   Sep        100.0          30.0
# 24514              512 MB RAM  2018.0   Sep         47.0          17.0
# 38983                4 GB RAM  2020.0   May          NaN           NaN
# 9523                      NaN     NaN  None          NaN           NaN
# 44695                4 GB RAM  2021.0   Mar          NaN           NaN
# 6677    2 GB(XP)/ 2 GB(Vista)  2013.0   Jan         73.0          76.0
# 53416                     NaN  2017.0   Jul          NaN           NaN
#
#        supported_language     price  pegi_rated  windows  mac  linux  VR
# 61448                 2.0   24999.0           1        1    0      0   0
# 55535                 5.0  249999.0           1        1    0      0   0
# 27392                 7.0   59999.0           0        1    0      0   0
# 10784                 4.0   17499.0           0        1    1      0   0
# 24514                 2.0    8499.0           0        1    0      0   0
# 38983                11.0  169999.0           0        1    0      0   0
# 9523                  NaN  166826.0           0        1    1      1   0
# 44695                 6.0  139999.0           0        1    0      0   0
# 6677                  7.0    9299.0           1        1    1      1   0
# 53416                 2.0   18999.0           0        1    0      0   0

# %% [markdown]
# #### remap `ram`

# %%
df_ram = df_platform.copy()
df_ram.loc[df_ram['ram'].str.lower().str.contains('9 gb', na=False),'ram'] = '9 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('8 gb|8000 mb|８ gb|8gb|8.0 gb|8\+ gb', na=False),'ram'] = '8 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('7 gb', na=False),'ram'] = '7 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('6 gb|6000 mb|６ gb', na=False),'ram'] = '6 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('5 gb|5000 mb', na=False),'ram'] = '5 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('4 gb|4096 mb|4000 mb|4gb|４ gb|4.00 gb|4g|4 ram gb', na=False),'ram'] = '4 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('3 gb|3000 mb|3 go mb|3gb', na=False),'ram'] = '3 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('2 gb|2048|2000 mb|2gb|1536 mb|2.0 gb|2000 gb|２ gb|1.5gb|2.0gb|2g', na=False),'ram'] = '2 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('1 gb|1024|1000 mb|1gb|800 mb|750 mb|1280 mb|700 mb|900 mb|１ gb|1\+', na=False),'ram'] = '1 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('512|500 mb|400 mb|512mb|600 mb|597 mb|320 mb|420 mb|500mb|349 mb', na=False),'ram'] = '512 MB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('256 gb|200 mb|300 mb|250 mb|256mb|220 mb|256 ram', na=False),'ram'] = '256 MB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('16.0 gb', na=False),'ram'] = '16 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('12.00 gb', na=False),'ram'] = '12 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('10 gb', na=False),'ram'] = '10 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('128 mb|64m|70 mb|100 mb|150 mb|16 mb|8 mb|2 mb|1 mb|4 mb|50 mb|3 mb|6 mb|10 mb|128mb|80 mb|4 ram mb|30 mb|40 mb|25 mb|5 mb|120 mb|64 mb|90 mb|60 mb|95 mb|65 mb|64mb|16mb|100以上|32mb|97 mb|20 mb|99 mb|4mb|69 mb|59 mb', na=False),'ram'] = '<128 MB'
df_ram.loc[~df_ram['ram'].str.lower().str.contains('16 gb|12 gb|10 gb|9 gb|8 gb|7 gb|6 gb|5 gb|4 gb|3 gb|2 gb|1 gb|512 mb|256 mb|<128 mb', na=False),'ram'] = 'Unknown'
df_ram['ram'].value_counts()
# Out:
# 4 GB       13536
# 2 GB       13186
# Unknown    11849
# <128 MB     8638
# 1 GB        8510
# 8 GB        6431
# 6 GB        1945
# 3 GB         658
# 5 GB         109
# 10 GB         17
# 7 GB           4
# 9 GB           2
# 12 GB          1
# 16 GB          1
# Name: ram, dtype: int64

# %%
df_ram.sample(10)
# Out:
#                                                    title         developer  \
# 57198                             Life of Lon: Chapter 1    Block Interval
# 22320              The Witcher 3: Wild Hunt - NEW GAME +    CD PROJEKT RED
# 50679                                   Mondrian Squares  LH Games Limited
# 8797                        Tricky Towers - Candy Bricks        WeirdBeard
# 57866                                        Riders 2491        GoeX Games
# 18858                               StarShip Constructor           SSCTEAM
# 4172                           OMSI 2 Add-on Rheinhausen     Halycon Media
# 3058                                     Coloring Game 4         L. Stotch
# 16570                                       Space Kettle     Maxkres Games
# 16705  Driver Fusion - The Best Driver & Device Solution            Treexy
#
#               publisher  overall_reviews  \
# 57198    Block Interval  Mostly Positive
# 22320               NaN    Very Positive
# 50679  LH Games Limited   3 user reviews
# 8797                NaN         Positive
# 57866        GoeX Games            Mixed
# 18858           SSCTEAM            Mixed
# 4172      Halycon Media    Very Positive
# 3058          L. Stotch    Very Positive
# 16570     Maxkres Games         Positive
# 16705            Treexy  Mostly Positive
#
#                                                     tags      ram    year  \
# 57198                                Adventure,VR,Puzzle     4 GB  2017.0
# 22320                                                RPG     6 GB  2015.0
# 50679  Strategy,Casual,Puzzle,Procedural Generation,L...  Unknown  2021.0
# 8797                                        Indie,Casual     1 GB  2017.0
# 57866  Action,Arcade,Shooter,Bullet Hell,Shoot 'Em Up...     2 GB  2020.0
# 18858       Indie,Space,Building,Early Access,Sandbox,2D     2 GB  2017.0
# 4172   Simulation,Driving,Realistic,Singleplayer,Modd...     4 GB  2016.0
# 3058   Free to Play,Indie,Casual,Design & Illustratio...     1 GB  2021.0
# 16570  Difficult,Singleplayer,Physics,Psychological H...     4 GB  2021.0
# 16705  Free to Play,Indie,Utilities,Software Training...  <128 MB  2013.0
#
#       month  user_rating  total_review  supported_language     price  \
# 57198   Jun         72.0          43.0                 1.0       0.0
# 22320   Aug         91.0         463.0                16.0       0.0
# 50679   Dec          NaN           NaN                 1.0    8499.0
# 8797    Feb        100.0          20.0                18.0    9299.0
# 57866   Jul         63.0          11.0                 1.0   24999.0
# 18858   Jul         67.0         237.0                 2.0   45999.0
# 4172    Oct         80.0         115.0                 2.0  253532.0
# 3058    Jul         86.0          23.0                29.0       0.0
# 16570   Feb         82.0          28.0                 1.0   49999.0
# 16705   May         72.0         321.0                29.0       NaN
#
#        pegi_rated  windows  mac  linux  VR
# 57198           0        1    0      0   0
# 22320           1        1    0      0   0
# 50679           0        1    0      0   0
# 8797            1        1    1      1   0
# 57866           0        1    1      1   0
# 18858           0        1    0      0   0
# 4172            0        1    0      0   0
# 3058            0        1    0      0   0
# 16570           0        1    1      0   0
# 16705           0        1    0      0   0

# %% [markdown]
# #### remap `overall_reviews`

# %%
df_or = df_ram.copy()
df_or.loc[~df_or['overall_reviews'].str.contains('Positive|Negative|Very|Overwhelmingly|Mixed|Mostly', na=False),'overall_reviews'] = '<10 reviews'
df_or['overall_reviews'].value_counts()
# Out:
# <10 reviews                26699
# Very Positive              10628
# Mixed                       9458
# Positive                    9079
# Mostly Positive             6749
# Mostly Negative             1559
# Overwhelmingly Positive      417
# Negative                     234
# Very Negative                 57
# Overwhelmingly Negative        7
# Name: overall_reviews, dtype: int64

# %%
df_or.sample(5)
# Out:
#                                                 title              developer  \
# 6854                    Araha : Curse of Yieun Island               Palmsoft
# 55589                                     School Idol  Fury Games Production
# 29721          TD Worlds + Original Soundtrack Bundle                    NaN
# 14896                                          人间-OST                    白露社
# 38692  White Day - Apple School Uniform - Hee-Min Lee           SONNORI Corp
#
#                    publisher  overall_reviews  \
# 6854                Palmsoft            Mixed
# 55589  Fury Games Production  Mostly Negative
# 29721                    NaN      <10 reviews
# 14896         PeriScope Game         Positive
# 38692     PQube,SONNORI Corp      <10 reviews
#
#                                                     tags      ram    year  \
# 6854              Indie,Adventure,Horror,Survival Horror     8 GB  2020.0
# 55589  Sexual Content,Nudity,Violent,Action,Adventure...     4 GB  2018.0
# 29721                                                NaN  Unknown     NaN
# 14896                  Adventure,Casual,Simulation,Indie     2 GB  2019.0
# 38692                             Action,Adventure,Indie     4 GB  2017.0
#
#       month  user_rating  total_review  supported_language     price  \
# 6854    Jan         62.0         197.0                10.0   99999.0
# 55589   Jul         24.0          29.0                 3.0   17499.0
# 29721  None          NaN           NaN                 NaN  106398.0
# 14896   May        100.0          25.0                 2.0    8499.0
# 38692   Aug          NaN           NaN                 9.0   18999.0
#
#        pegi_rated  windows  mac  linux  VR
# 6854            0        1    0      0   0
# 55589           0        1    0      0   0
# 29721           0        1    0      0   0
# 14896           0        1    0      0   0
# 38692           0        1    0      0   0

# %% [markdown]
# #### reformat and remap `tags`

# %%
df_tags = df_or.copy()
df_tags.loc[df_tags['tags'].isna()==True,'tags'] = 'No Tags'
df_tags['tags'] = df_tags['tags'].str.split(',')
#df_tags['tags'] = df_tags['tags'].replace(',', '","')
#df_tags['tags'] = '["' + df_tags['tags'] + '"]'
df_tags.sample(10)
# Out:
#                                                    title  \
# 17661                                        Empire Live
# 41254           FORCED SHOWDOWN - Deluxe Edition Content
# 24555                                          Odd||Even
# 31032                                FROM WRECK TO WRECK
# 64773  Warhammer 40,000: Inquisitor - Martyr - Monota...
# 64183                       Lance A Lot: Classic Edition
# 33375  Idle Champions - Star the Displacer Beast Kitt...
# 16902                                         Lanternium
# 8420                                      Adorable Crush
# 63677                           Shadow Ninja: Apocalypse
#
#                          developer                    publisher  \
# 17661                Osmose Studio                Osmose Studio
# 41254                    BetaDwarf                          NaN
# 24555                 kylix studio                 kylix studio
# 31032                          NaN                          NaN
# 64773                 NeocoreGames                 NeocoreGames
# 64183                    Brimstone                    Brimstone
# 33375  Codename Entertainment Inc.  Codename Entertainment Inc.
# 16902        Blazing Planet Studio        Blazing Planet Studio
# 8420                  Mature Games                 Mature Games
# 63677           Boogygames Studios           Boogygames Studios
#
#        overall_reviews                                               tags  \
# 17661         Positive  [Indie, Strategy, RPG, Early Access, Multiplayer]
# 41254      <10 reviews                     [Strategy, Action, RPG, Indie]
# 24555            Mixed  [Experimental, Difficult, Education, Puzzle, L...
# 31032      <10 reviews                                          [No Tags]
# 64773            Mixed     [Action, Adventure, RPG, Indie, Gore, Violent]
# 64183    Very Positive  [Indie, Action, Casual, 4 Player Local, Local ...
# 33375      <10 reviews  [Strategy, Action, Adventure, Free to Play, In...
# 16902         Positive  [Puzzle Platformer, Character Action Game, Dif...
# 8420   Mostly Positive  [Dating Sim, Hentai, Casual, Visual Novel, Mat...
# 63677            Mixed  [Action, Indie, Adventure, Casual, Strategy, P...
#
#            ram    year month  user_rating  total_review  supported_language  \
# 17661     4 GB  2020.0   May         84.0          13.0                 2.0
# 41254     4 GB  2016.0   Mar          NaN           NaN                 1.0
# 24555  <128 MB  2016.0   Apr         53.0          30.0                 1.0
# 31032  Unknown     NaN  None          NaN           NaN                 NaN
# 64773     4 GB  2018.0   Nov         63.0          11.0                10.0
# 64183     2 GB  2016.0   Oct         85.0          55.0                11.0
# 33375  Unknown  2021.0   Nov          NaN           NaN                 1.0
# 16902     2 GB  2019.0   Apr         86.0          36.0                11.0
# 8420      1 GB  2020.0   Oct         77.0         515.0                 4.0
# 63677     1 GB  2015.0   Nov         57.0         132.0                 1.0
#
#           price  pegi_rated  windows  mac  linux  VR
# 17661   82999.0           0        1    0      0   0
# 41254   59999.0           0        1    1      1   0
# 24555  108999.0           0        1    0      0   0
# 31032  179098.0           0        1    0      0   0
# 64773   17499.0           0        1    0      0   0
# 64183   39999.0           0        1    0      0   0
# 33375   69999.0           0        1    1      0   0
# 16902   69999.0           0        1    1      1   0
# 8420    24999.0           0        1    0      0   0
# 63677   18999.0           1        1    1      0   0

# %%
def to_1D(series): #
 return pd.Series([x for _list in series for x in _list])

# %% [markdown]
# #### reformat and remap `developer`

# %%
df_dev = df_tags.copy()
df_dev.loc[df_dev['developer'].isna()==True,'developer'] = 'Unknown'
df_dev['developer'] = df_dev['developer'].str.split(',')
#df_tags['tags'] = df_tags['tags'].replace(',', '","')
#df_tags['tags'] = '["' + df_tags['tags'] + '"]'
df_dev.sample(10)
# Out:
#                                     title               developer  \
# 13784                     RPGツクールMV×パルフォン               [Unknown]
# 7099                                KAPIA               [2 FOR 2]
# 50218                     Trigger Dungeon                [171Dev]
# 33152  War Thunder - Chinese Starter Pack  [Gaijin Entertainment]
# 34384                       Pixel Shooter           [Fabio Cunha]
# 937              Sally Face - Episode One        [Portable Moose]
# 61145                    Kingdom of Dinza    [Starstrike Studios]
# 59204            Hunahpu Quest. Mechanoid            [Rumata Lab]
# 20710    The Coma: Recut - Deluxe Edition               [Unknown]
# 67340       Dying Light - Snow Ops Bundle              [Techland]
#
#                      publisher          overall_reviews  \
# 13784                      NaN              <10 reviews
# 7099                   2 FOR 2                 Positive
# 50218                   171Dev              <10 reviews
# 33152  Gaijin Distribution KFT              <10 reviews
# 34384              Fabio Cunha          Mostly Negative
# 937             Portable Moose  Overwhelmingly Positive
# 61145       Starstrike Studios                 Positive
# 59204       ValkyrieInitiative          Mostly Positive
# 20710                      NaN              <10 reviews
# 67340                      NaN            Very Positive
#
#                                                     tags      ram    year  \
# 13784                                          [No Tags]  Unknown     NaN
# 7099   [Comedy, Adventure, Point & Click, Puzzle, Fun...     4 GB  2022.0
# 50218  [Action, Platformer, 2D Platformer, Precision ...  <128 MB  2022.0
# 33152  [Action, Free to Play, Massively Multiplayer, ...     4 GB  2022.0
# 34384  [Side Scroller, 2D Platformer, Casual, Difficu...     2 GB  2017.0
# 937    [Story Rich, Psychological Horror, Dark, Horro...     4 GB  2016.0
# 61145  [Adventure, RPG, Top-Down, 2D, Open World, Pro...  Unknown  2021.0
# 59204  [Indie, Adventure, Platformer, Aliens, Puzzle ...  <128 MB  2018.0
# 20710                                          [No Tags]  Unknown     NaN
# 67340                                      [RPG, Action]     4 GB  2021.0
#
#       month  user_rating  total_review  supported_language     price  \
# 13784  None          NaN           NaN                 NaN  518998.0
# 7099    Jan        100.0          19.0                 7.0  108999.0
# 50218   Jan          NaN           NaN                 1.0   24999.0
# 33152   Mar          NaN           NaN                18.0  139999.0
# 34384   Jul         32.0          31.0                 1.0   84999.0
# 937     Dec         97.0         269.0                 6.0   25999.0
# 61145   Dec         90.0          11.0                 1.0   59999.0
# 59204   Jan         79.0          24.0                 2.0   32999.0
# 20710  None          NaN           NaN                 NaN  162748.0
# 67340   Dec         80.0          95.0                17.0   17499.0
#
#        pegi_rated  windows  mac  linux  VR
# 13784           0        1    0      0   0
# 7099            0        1    0      0   0
# 50218           0        1    0      0   0
# 33152           1        1    1      1   0
# 34384           0        1    0      0   0
# 937             1        1    1      1   0
# 61145           0        1    0      0   0
# 59204           0        1    0      0   0
# 20710           0        1    1      1   0
# 67340           1        1    1      1   0

# %%
to_1D(df_dev['developer']).value_counts().head(100)
# Out:
# Unknown                    5214
# Ubisoft - San Francisco    1166
#  LTD.                      1137
#  LLC                       1108
# KOEI TECMO GAMES CO.        974
#                            ...
# TK.Projects                  50
# Techland                     50
# Orange_Juice                 49
# AMAX Interactive             49
# Harmonix Music Systems       49
# Length: 100, dtype: int64

# %% [markdown]
# #### reformat and remap `publisher`

# %%
df_pub = df_dev.copy()
df_pub.loc[df_pub['publisher'].isna()==True,'publisher'] = 'Unknown'
df_pub['publisher'] = df_pub['publisher'].str.split(',')
df_pub.sample(10)
# Out:
#                                                    title  \
# 24679                                   Shoot 'Em Up Kit
# 56076                   RPG Maker MZ - DS+ Resource Pack
# 44981                           Knights and Castles(1.0)
# 33519                                   MadOut Open City
# 16199    Aerofly FS 2 - France VFR - Paris-Ile-de-France
# 38415                                   Agony Soundtrack
# 44163  VR Time Machine Travelling in history: Visit a...
# 52927                              Receiver 2 Soundtrack
# 14529                             Super Clown Adventures
# 35044                                       150,000 B.C.
#
#                               developer            publisher  overall_reviews  \
# 24679                    [Tall Studios]       [Tall Studios]            Mixed
# 56076   [Gotcha Gotcha Games, KADOKAWA]             [Degica]      <10 reviews
# 44981                       [Pixelabor]            [Unknown]      <10 reviews
# 33519                    [MadOut Games]       [MadOut Games]  Mostly Negative
# 16199                      [France VFR]              [IPACS]  Mostly Positive
# 38415                  [Madmind Studio]     [Madmind Studio]      <10 reviews
# 44163               [William at Oxford]  [William at Oxford]      <10 reviews
# 52927                   [Wolfire Games]      [Wolfire Games]      <10 reviews
# 14529  [Tero Lunkka, Valkeala Software]        [Tero Lunkka]         Positive
# 35044                          [carrot]       [Garage Games]  Mostly Negative
#
#                                                     tags      ram    year  \
# 24679  [Utilities, Early Access, Shoot 'Em Up, Animat...     4 GB  2015.0
# 56076       [RPG, Web Publishing, Design & Illustration]  Unknown  2020.0
# 44981                                [Free to Play, RPG]  <128 MB  2021.0
# 33519  [Racing, Action, Open World, Simulation, Indie...  <128 MB  2016.0
# 16199                                [Indie, Simulation]     8 GB  2020.0
# 38415                         [Action, Adventure, Indie]     2 GB  2019.0
# 44163  [Casual, Exploration, VR, Medieval, Singleplayer]     8 GB  2020.0
# 52927                                          [No Tags]  Unknown  2020.0
# 14529  [Adventure, Arcade, Platformer, Walking Simula...     2 GB  2021.0
# 35044             [Indie, Casual, Adventure, Platformer]  <128 MB  2018.0
#
#       month  user_rating  total_review  supported_language     price  \
# 24679   Jun         59.0          27.0                 1.0  269999.0
# 56076   Sep          NaN           NaN                 2.0  139999.0
# 44981   Oct          NaN           NaN                 1.0   39999.0
# 33519   Mar         37.0         236.0                 2.0   69999.0
# 16199   Mar         73.0          15.0                 3.0  159999.0
# 38415   Feb          NaN           NaN                 1.0   32999.0
# 44163   Aug          NaN           NaN                11.0   69999.0
# 52927   Apr          NaN           NaN                 NaN   69999.0
# 14529   Feb         82.0          28.0                 1.0    8499.0
# 35044   May         30.0          33.0                 1.0    8499.0
#
#        pegi_rated  windows  mac  linux  VR
# 24679           0        1    0      0   0
# 56076           0        1    1      0   0
# 44981           0        1    0      0   0
# 33519           0        1    1      1   1
# 16199           0        1    1      0   0
# 38415           1        1    0      0   0
# 44163           0        1    0      0   0
# 52927           0        0    0      0   0
# 14529           0        1    0      0   0
# 35044           0        1    0      0   0

# %%
to_1D(df_pub['publisher']).value_counts().head(60)
# Out:
# Unknown                       10180
# Degica                         1078
#  LTD.                           906
#  Inc.                           862
# KOEI TECMO GAMES CO.            788
#  Ltd.                           678
# Dovetail Games - Trains         514
# CAPCOM Co.                      466
# Paradox Interactive             425
# Big Fish Games                  380
# BANDAI NAMCO Entertainment      380
# SEGA                            379
# Square Enix                     375
# Electronic Arts                 325
# D3 PUBLISHER                    324
# Ubisoft                         319
#  LLC                            308
# XSEED Games                     289
# Marvelous USA                   283
# THQ Nordic                      281
# Feral Interactive (Mac)         269
# 2K                              228
# Dovetail Games - Flight         228
# Slitherine Ltd.                 224
# Idea Factory International      212
# Feral Interactive (Linux)       204
# 8floor                          197
# NIS America                     188
# Sekai Project                   188
# Dovetail Games                  177
# Aerosoft GmbH                   166
# PQube                           161
# Rebellion                       159
# Xbox Game Studios               158
# PLAYISM                         156
# Devolver Digital                148
# Focus Home Interactive          147
# Capcom                          147
# Choice of Games                 146
# Nacon                           144
# 1C Entertainment                138
# Strategy First                  136
# Plug In Digital                 135
# HH-Games                        133
# Milestone S.r.l.                132
# 505 Games                       120
# Activision                      115
# Deep Silver                     114
# N3V Games                       109
# Alawar Entertainment            108
# SCS Software                    107
# Bethesda Softworks              107
# tinyBuild                       106
# Daedalic Entertainment          105
# Ziggurat                        105
# Aspyr (Mac)                     100
# PlayWay S.A.                    100
# Nightdive Studios                99
# Kalypso Media Digital            98
# Gotcha Gotcha Games              97
# dtype: int64

# %% [markdown]
# ## data understanding

# %%
df_final = df_pub.copy()
df_final.sample(5)
# Out:
#                                                    title  \
# 9383                  Upgrade to Movavi Video Suite 2022
# 28693                                   Summer Nightmare
# 37683  Moonlighter: Between Dimensions Original Sound...
# 31107                        Forgotten Places Collection
# 16716                      Dragon Castle: The Board Game
#
#                      developer         publisher overall_reviews  \
# 9383                 [Unknown]         [Unknown]     <10 reviews
# 28693  [Team Summer Nightmare]    [Elkibe Games]           Mixed
# 37683            [Digital Sun]         [Unknown]     <10 reviews
# 31107                [Unknown]         [Unknown]     <10 reviews
# 16716        [Studio Clangore]  [Horrible Guild]        Positive
#
#                                                     tags      ram    year  \
# 9383                                           [No Tags]  Unknown     NaN
# 28693  [Free to Play, Anime, Visual Novel, Horror, Go...     1 GB  2017.0
# 37683  [Action, Adventure, Indie, RPG, Roguelite, Sou...  Unknown  2019.0
# 31107                                          [No Tags]  Unknown     NaN
# 16716  [Board Game, Casual, Tabletop, Asynchronous Mu...     1 GB  2019.0
#
#       month  user_rating  total_review  supported_language     price  \
# 9383   None          NaN           NaN                 NaN  978600.0
# 28693   Dec         52.0         466.0                 2.0       0.0
# 37683   Nov          NaN           NaN                 NaN   17499.0
# 31107  None          NaN           NaN                 NaN   51998.0
# 16716   Dec         92.0          26.0                 5.0   64999.0
#
#        pegi_rated  windows  mac  linux  VR
# 9383            0        1    0      0   0
# 28693           0        1    1      1   0
# 37683           0        0    0      0   0
# 31107           0        1    1      0   0
# 16716           0        1    1      0   0

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64887 entries, 0 to 68467
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               64887 non-null  object
#  1   developer           64887 non-null  object
#  2   publisher           64887 non-null  object
#  3   overall_reviews     64887 non-null  object
#  4   tags                64887 non-null  object
#  5   ram                 64887 non-null  object
#  6   year                59907 non-null  float64
#  7   month               59903 non-null  object
#  8   user_rating         38188 non-null  float64
#  9   total_review        38188 non-null  float64
#  10  supported_language  57750 non-null  float64
#  11  price               64366 non-null  float64
#  12  pegi_rated          64887 non-null  int32
#  13  windows             64887 non-null  int32
#  14  mac                 64887 non-null  int32
#  15  linux               64887 non-null  int32
#  16  VR                  64887 non-null  int32
# dtypes: float64(5), int32(5), object(7)
# memory usage: 7.7+ MB

# %%
df_final.describe()
# Out:
#                year   user_rating   total_review  supported_language  \
# count  59907.000000  38188.000000   38188.000000        57750.000000
# mean    2018.223396     76.416963     218.957971            4.774130
# std        2.773410     18.492328    4440.137845            5.349063
# min     1997.000000      0.000000      10.000000            1.000000
# 25%     2017.000000     66.000000      18.000000            1.000000
# 50%     2019.000000     80.000000      40.000000            2.000000
# 75%     2020.000000     91.000000     122.000000            7.000000
# max     2077.000000    100.000000  558563.000000           29.000000
#
#               price    pegi_rated       windows           mac         linux  \
# count  6.436600e+04  64887.000000  64887.000000  64887.000000  64887.000000
# mean   8.363383e+04      0.201181      0.965232      0.283632      0.167707
# std    1.588174e+05      0.400886      0.183193      0.450764      0.373609
# min    0.000000e+00      0.000000      0.000000      0.000000      0.000000
# 25%    2.499900e+04      0.000000      1.000000      0.000000      0.000000
# 50%    5.299900e+04      0.000000      1.000000      0.000000      0.000000
# 75%    9.599900e+04      0.000000      1.000000      1.000000      0.000000
# max    8.990155e+06      1.000000      1.000000      1.000000      1.000000
#
#                  VR
# count  64887.000000
# mean       0.009493
# std        0.096971
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df_final[['overall_reviews','ram']].describe()
# Out:
#        overall_reviews    ram
# count            64887  64887
# unique              10     14
# top        <10 reviews   4 GB
# freq             26699  13536

# %% [markdown]
# ## export csv

# %%
df_final.to_csv('for_EDA.csv', index=False)

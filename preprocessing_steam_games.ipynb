# %% [markdown]
# ## import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# ## load dataset

# %%
raw = pd.read_csv('steam_games.csv')
raw.sample(5)
# Out:
#                                                     title  \
# 39147   The Legend of Heroes: Trails of Cold Steel III...
# 70141                                       Revived Souls
# 109678                      NASCAR '15 2016 Season Update
# 103913                         Pirate Island Mini Golf VR
# 31170   In Search of the Most Dangerous Town on the In...
#
#                                                       url  \
# 39147   https://store.steampowered.com/app/1262419/The...
# 70141   https://store.steampowered.com/app/1653460/Rev...
# 109678  https://store.steampowered.com/app/515300/NASC...
# 103913  https://store.steampowered.com/app/1256870/Pir...
# 31170   https://store.steampowered.com/app/380890/In_S...
#
#                                                     image  release_date  \
# 39147   https://cdn.akamai.steamstatic.com/steam/apps/...  23 Mar, 2020
# 70141   https://cdn.akamai.steamstatic.com/steam/apps/...      Feb 2024
# 109678  https://cdn.akamai.steamstatic.com/steam/apps/...  29 Aug, 2016
# 103913  https://cdn.akamai.steamstatic.com/steam/apps/...   8 Jun, 2020
# 31170   https://cdn.akamai.steamstatic.com/steam/apps/...  18 Jun, 2015
#
#              platforms discount_rate original_price discounted_price  \
# 39147          Windows           NaN      Rp 17 499              NaN
# 70141   Windows,Mac OS           NaN            NaN              NaN
# 109678         Windows           NaN           Free              NaN
# 103913         Windows           NaN      Rp 59 999              NaN
# 31170              NaN           NaN           Free              NaN
#
#                                        developer                 publisher  \
# 39147   Nihon Falcom,Engine Software BV,PH3 GmbH         NIS America, Inc.
# 70141                            Destinate Games           Destinate Games
# 109678                                 Eutechnyx  Dusenberry Martin Racing
# 103913                          Serious Tangents          Serious Tangents
# 31170                                        NaN                       NaN
#
#         ... whole_reviews                                        description  \
# 39147   ...           NaN                                                NaN
# 70141   ...           NaN  Explore a Celtic world full of magic devices a...
# 109678  ...           NaN                                                NaN
# 103913  ...           NaN  Pirate Island Mini Golf VR is a single or mult...
# 31170   ...           NaN  Râmnicu Vâlcea, Romania has only 120,000 resid...
#
#                                                      tags  \
# 39147                                                 RPG
# 70141   Adventure,Puzzle,Story Rich,Philosophical,Medi...
# 109678                                             Racing
# 103913  Early Access,Casual,Sports,VR,Mini Golf,Atmosp...
# 31170                                 Hacking,Documentary
#
#                              genre  \
# 39147                          RPG
# 70141          Adventure,Indie,RPG
# 109678                      Racing
# 103913  Casual,Sports,Early Access
# 31170                          NaN
#
#                                                 processor           ram  \
# 39147                                                 NaN           NaN
# 70141                                               2 Ghz      2 GB RAM
# 109678                 AMD Athlon 64 X2 6000 (2*3000 MHz)   2048 MB RAM
# 103913   Intel(R) Core(TM) i7-7700 CPU @ 3.60GHz, 3601...     16 GB RAM
# 31170                      Intel Core 2 or AMD equivalent      1 GB RAM
#
#                                    graphic_card rating  \
# 39147                                       NaN    NaN
# 70141    256 mb video memory, shader model 3.0+    NaN
# 109678                          GeForce 8800 GT    NaN
# 103913                  NVIDIA GeForce GTX 1070    NaN
# 31170                                       NaN    NaN
#
#                        language metacriticts
# 39147   English,French,Japanese          NaN
# 70141                   English          NaN
# 109678                  English          NaN
# 103913                  English          NaN
# 31170                   English          NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## data understanding

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121904 entries, 0 to 121903
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   title             121893 non-null  object
#  1   url               121904 non-null  object
#  2   image             121904 non-null  object
#  3   release_date      113850 non-null  object
#  4   platforms         117576 non-null  object
#  5   discount_rate     2941 non-null    object
#  6   original_price    109675 non-null  object
#  7   discounted_price  2935 non-null    object
#  8   developer         113921 non-null  object
#  9   publisher         103890 non-null  object
#  10  overall_reviews   78125 non-null   object
#  11  recent_reviews    78125 non-null   object
#  12  whole_reviews     5773 non-null    object
#  13  description       75925 non-null   object
#  14  tags              112020 non-null  object
#  15  genre             111334 non-null  object
#  16  processor         100264 non-null  object
#  17  ram               99696 non-null   object
#  18  graphic_card      93894 non-null   object
#  19  rating            18891 non-null   object
#  20  language          110255 non-null  object
#  21  metacriticts      2223 non-null    float64
# dtypes: float64(1), object(21)
# memory usage: 20.5+ MB

# %% [markdown]
# Observations:
# - `url`,`image`,`discount_rate`,`discounted_price`,`description` drop
# - `release_date` extract month and year
# - `platfoms`,`developer`,`publisher`,`tags` split
# - `original_price` change data type (extract price)
# - `text_reviews` extract rating (`user_rating`) and total user reviews (`total_reviews`)
# - `language` extract number of language (`language`)
# - `metacriticts` too much missing values, drop

# %%
raw.describe()
# Out:
#        metacriticts
# count   2223.000000
# mean      80.931174
# std        4.404322
# min       75.000000
# 25%       77.000000
# 50%       80.000000
# 75%       84.000000
# max       97.000000

# %%
raw.describe(include='object')
# Out:
#                     title                                                url  \
# count              121893                                             121904
# unique             103975                                             121904
# top     Game + Soundtrack  https://store.steampowered.com/app/1172470/Ape...
# freq                   22                                                  1
#
#                                                     image release_date  \
# count                                              121904       113850
# unique                                             104388         5956
# top     https://cdn.akamai.steamstatic.com/steam/apps/...         2022
# freq                                                    6         1194
#
#        platforms discount_rate original_price discounted_price  \
# count     117576          2941         109675             2935
# unique        13            84           5094             1023
# top      Windows          -50%       Rp 8 499         Rp 4 249
# freq       83499           545           9675              200
#
#                   developer    publisher  ...  \
# count                113921       103890  ...
# unique                40378        34416  ...
# top     SmiteWorks USA, LLC  TigerQiuQiu  ...
# freq                   2375         2132  ...
#
#                                       recent_reviews  \
# count                                          78125
# unique                                         13798
# top     - Need more user reviews to generate a score
# freq                                           32928
#
#                                             whole_reviews  \
# count                                                5773
# unique                                               4995
# top     - 97% of the 182 user reviews for this game ar...
# freq                                                    5
#
#                                          description    tags         genre  \
# count                                          75925  112020        111334
# unique                                         60557   60019          1846
# top     Find the objects that are hidden on the map.  Action  Action,Indie
# freq                                              20    2414          5825
#
#                            processor        ram                graphic_card  \
# count                         100264      99696                       93894
# unique                         17369       1006                       20152
# top      1.6 GHz or higher processor   4 GB RAM   Graphics card recommended
# freq                            2302      26055                        2303
#
#                                                    rating language
# count                                               18891   110255
# unique                                                  9     9687
# top     https://store.akamai.steamstatic.com/public/sh...  English
# freq                                                 5836    52491
#
# [4 rows x 21 columns]

# %% [markdown]
# observations:
# - `rating` data is wrong, consider drop or rescrape data
# - `tags` too much unique value, consider to create new columns tag that has been aggregated

# %% [markdown]
# ## data preprocessing (format)

# %% [markdown]
# ### drop duplicates and uninformative columns

# %%
df_drop = raw.copy()
df_drop.drop_duplicates(subset='title',inplace=True)
df_drop['title'].duplicated().sum()
# Out:
# 0

# %%
drop = ['url','image','discount_rate','discounted_price','description','metacriticts','processor','graphic_card'] #these variables unable to show any kind of valuable information that can be used for current analysis and machine learning model, consider to be used for other analysis
df_drop = df_drop.drop(labels=drop,axis=1)
df_drop.sample(10)
# Out:
#                                                    title  release_date  \
# 63916                     Animated Puzzles - Spooky Pack  29 Oct, 2020
# 50814                                       Soviet Souls   7 May, 2019
# 24524                                    Eternal Fantasy  18 Oct, 2018
# 15980                                      Range is HOT!   9 Mar, 2021
# 33174                              Data Bundle for gifts           NaN
# 748                            Cities: Skylines - Campus  21 May, 2019
# 37618  Rover Mechanic Simulator - Perseverance Rover DLC  18 Feb, 2021
# 44800         Zaccaria Pinball - House of Diamonds Table  16 Jun, 2016
# 36680  Fantasy Grounds - 5E: Book of Lost Spells (Fif...  18 Apr, 2016
# 49243  Fantasy Grounds - Starfinder Flip-Tiles - City...  29 Mar, 2022
#
#                   platforms original_price                     developer  \
# 63916  Windows,Mac OS,Linux      Rp 24 999                        Mexond
# 50814  Windows,Mac OS,Linux      Rp 17 499  Fang's Lab,DP Games,Flatcoon
# 24524               Windows      Rp 69 999         Circus,YAMAYURI GAMES
# 15980               Windows     Rp 139 999            Winter Bear Studio
# 33174               Windows     Rp 174 990                           NaN
# 748    Windows,Mac OS,Linux     Rp 109 199           Colossal Order Ltd.
# 37618               Windows      Rp 48 999               ▲ Pyramid Games
# 44800  Windows,Mac OS,Linux      Rp 18 999              Magic Pixel Kft.
# 36680               Windows     Rp 135 999           SmiteWorks USA, LLC
# 49243        Windows,Mac OS     Rp 108 999           SmiteWorks USA, LLC
#
#                           publisher  overall_reviews  \
# 63916                        Mexond              NaN
# 50814  Fang's Lab,DP Games,Flatcoon   6 user reviews
# 24524                    SakuraGame            Mixed
# 15980            Winter Bear Studio  Mostly Positive
# 33174                           NaN              NaN
# 748             Paradox Interactive  Mostly Positive
# 37618            Pyramid Games S.A.   5 user reviews
# 44800              Magic Pixel Kft.   1 user reviews
# 36680                           NaN   2 user reviews
# 49243                           NaN              NaN
#
#                                           recent_reviews whole_reviews  \
# 63916                                                NaN           NaN
# 50814       - Need more user reviews to generate a score           NaN
# 24524  - 68% of the 29 user reviews for this game are...           NaN
# 15980  - 77% of the 27 user reviews for this game are...           NaN
# 33174                                                NaN           NaN
# 748    - 76% of the 214 user reviews for this game ar...           NaN
# 37618       - Need more user reviews to generate a score           NaN
# 44800       - Need more user reviews to generate a score           NaN
# 36680       - Need more user reviews to generate a score           NaN
# 49243                                                NaN           NaN
#
#                                                     tags  \
# 63916                                       Indie,Casual
# 50814  Indie,Action,Adventure,Platformer,2D,Pixel Gra...
# 24524  Sexual Content,Nudity,Adventure,Indie,RPG,Visu...
# 15980  Simulation,Sports,VR,Competitive,Action,Shoote...
# 33174                                                NaN
# 748                     Simulation,Strategy,City Builder
# 37618  Indie,Simulation,Singleplayer,Replay Value,Fam...
# 44800              Free to Play,Casual,Simulation,Sports
# 36680  RPG,Indie,Strategy,Fantasy,Medieval,Party-Base...
# 49243           RPG,Indie,Strategy,Space,Sci-fi,Tabletop
#
#                                        genre        ram  \
# 63916                           Casual,Indie   2 GB RAM
# 50814                 Action,Adventure,Indie   1 GB RAM
# 24524                    Adventure,Indie,RPG   1 GB RAM
# 15980  Action,Simulation,Sports,Early Access   8 GB RAM
# 33174                                    NaN        NaN
# 748                      Simulation,Strategy   8 GB RAM
# 37618                       Indie,Simulation   8 GB RAM
# 44800  Casual,Free to Play,Simulation,Sports   2 GB RAM
# 36680                     Indie,RPG,Strategy   1 GB RAM
# 49243                     Indie,RPG,Strategy   1 GB RAM
#
#                                                   rating  \
# 63916                                                NaN
# 50814                                                NaN
# 24524                                                NaN
# 15980                                                NaN
# 33174                                                NaN
# 748    https://store.akamai.steamstatic.com/public/sh...
# 37618                                                NaN
# 44800                                                NaN
# 36680                                                NaN
# 49243                                                NaN
#
#                                                 language
# 63916  English,French,Italian,German,Spanish - Spain,...
# 50814                          English,Russian,Ukrainian
# 24524               English,Japanese,Traditional Chinese
# 15980                                            English
# 33174                                                NaN
# 748    English,French,German,Spanish - Spain,Polish,P...
# 37618  English,French,German,Simplified Chinese,Polis...
# 44800                                            English
# 36680                                            English
# 49243                                            English

# %% [markdown]
# ### data extraction and formatting

# %% [markdown]
# #### extract `month` and `year`

# %%
#define function to extract year
def extract_year(x):
    year = None
    if type(x) == list:
        for i in x:
            if len(i) == 4:
                year = i
                return year
            else: 
                year = None
        return year
    else:
        year = x
    return year

# %%
#df_drop[['date','month','year']] = df_drop['release_date'].str.split(' ', n=2 , expand=True)
df_extract = df_drop.copy()
month = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
#df_extract['year'] = df_extract['release_date'].str[-4:].apply(pd.to_numeric, errors=('coerce')) 
df_extract['year'] = df_extract['release_date'].str.findall('(\d+)').apply(lambda x: extract_year(x)).astype(float)
df_extract['month'] = df_extract['release_date'].str.findall("[a-zA-Z]+").str[0]
df_extract['month'] = df_extract['month'].replace(['August','June'],['Aug','Jun'])
df_extract.loc[~df_extract['month'].isin(month),'month'] = None
df_extract = df_extract.drop('release_date', axis=1) #drop release date
df_extract.sample(5)
# Out:
#                                              title       platforms  \
# 104874        RPG Maker MZ - OverWorld Battlebacks  Windows,Mac OS
# 82260                               The Great Race         Windows
# 87680                          Knight And Mourning  Windows,Mac OS
# 96199                          Cosmos Conquer Demo         Windows
# 103844  DFF NT: Laevateinn, Shantotto's 4th Weapon         Windows
#
#        original_price                               developer  \
# 104874      Rp 95 999                           Joel Steudler
# 82260       Rp 69 999                             Triumph LLC
# 87680             NaN                                 1actose
# 96199       Free Demo                            Paweł Wiecha
# 103844      Rp 12 000  Square Enix,KOEI TECMO GAMES CO., LTD.
#
#                publisher overall_reviews  \
# 104874            Degica             NaN
# 82260        Triumph LLC  7 user reviews
# 87680            1actose             NaN
# 96199   Iguana Mercenary             NaN
# 103844       Square Enix             NaN
#
#                                       recent_reviews whole_reviews  \
# 104874                                           NaN           NaN
# 82260   - Need more user reviews to generate a score           NaN
# 87680                                            NaN           NaN
# 96199                                            NaN           NaN
# 103844                                           NaN           NaN
#
#                                                      tags  \
# 104874           RPG,Web Publishing,Design & Illustration
# 82260   Racing,Action,Indie,Simulation,Adventure,Satir...
# 87680   Precision Platformer,Difficult,Platformer,2D P...
# 96199   Early Access,Casual,Strategy,Simulation,God Ga...
# 103844                                Action,Free to Play
#
#                                                 genre        ram  \
# 104874       RPG,Design & Illustration,Web Publishing        NaN
# 82260        Action,Adventure,Indie,Racing,Simulation   4 GB RAM
# 87680                   Action,Adventure,Casual,Indie   2 GB RAM
# 96199   Casual,Indie,Simulation,Strategy,Early Access   2 GB RAM
# 103844                            Action,Free to Play   8 GB RAM
#
#                                                    rating  \
# 104874                                                NaN
# 82260   https://store.akamai.steamstatic.com/public/sh...
# 87680                                                 NaN
# 96199                                                 NaN
# 103844  https://store.akamai.steamstatic.com/public/sh...
#
#                                                  language    year month
# 104874  English,Japanese,French,Italian,German,Spanish...  2020.0   Oct
# 82260                                     English,Russian  2018.0   May
# 87680                                             English  2022.0  None
# 96199                              English,Polish,Russian  2022.0   Jan
# 103844  English,French,Italian,German,Spanish - Spain,...  2019.0   Mar

# %% [markdown]
# #### extract `user_rating` and `total_reviews`

# %%
df_extract_2 = df_extract.copy()
df_extract_2['whole_reviews'] = df_extract_2['whole_reviews'].str.replace(',','')
df_extract_2['user_rating_all'] = df_extract_2['whole_reviews'].str.findall('(\d+)').str[0].astype(float)
df_extract_2['total_review_all'] = df_extract_2['whole_reviews'].str.findall('(\d+)').str[1].astype(float)
df_extract_2 = df_extract_2.drop('whole_reviews',axis=1)
df_extract_2.sample(5)
# Out:
#                                  title platforms original_price  \
# 36904                     The Last One   Windows      Rp 64 999
# 55274       DOA6 Raidou Deluxe Costume   Windows      Rp 19 000
# 97034  Tiger Tank 59 Ⅰ Rainstorm MP060   Windows       Rp 8 499
# 91810          Without A Roof (W.A.R.)   Windows     Rp 119 999
# 47746                  Struggling Ball   Windows      Rp 39 999
#
#                         developer                   publisher  \
# 36904  Phoenix Interactive Studio  Phoenix Interactive Studio
# 55274  KOEI TECMO GAMES CO., LTD.  KOEI TECMO GAMES CO., LTD.
# 97034                 TigerQiuQiu                 TigerQiuQiu
# 91810            New World Coders            New World Coders
# 47746             Struggling Ball             Struggling Ball
#
#        overall_reviews                                     recent_reviews  \
# 36904  Mostly Negative  - 32% of the 115 user reviews for this game ar...
# 55274   1 user reviews       - Need more user reviews to generate a score
# 97034              NaN                                                NaN
# 91810   2 user reviews       - Need more user reviews to generate a score
# 47746   3 user reviews       - Need more user reviews to generate a score
#
#                                                     tags  \
# 36904  Survival,Multiplayer,Zombies,Action,Adventure,...
# 55274          Action,Gore,Violent,Nudity,Sexual Content
# 97034  Action,Indie,Casual,Old School,Pixel Graphics,...
# 91810  Action,Indie,Simulation,Adventure,RPG,Massivel...
# 47746  Casual,Adventure,Action-Adventure,Runner,Parko...
#
#                                                    genre        ram  \
# 36904                Action,Adventure,Indie,Early Access   2 GB RAM
# 55274                                             Action   8 GB RAM
# 97034                                Action,Casual,Indie   4 GB RAM
# 91810  Action,Adventure,Indie,Massively Multiplayer,R...   8 GB RAM
# 47746                             Adventure,Casual,Indie   2 GB RAM
#
#                                                   rating  \
# 36904                                                NaN
# 55274  https://store.akamai.steamstatic.com/public/sh...
# 97034                                                NaN
# 91810                                                NaN
# 47746                                                NaN
#
#                                                 language    year month  \
# 36904  English,Turkish,French,German,Russian,Spanish ...  2018.0   Jan
# 55274  English,French,Italian,German,Spanish - Spain,...  2019.0   Aug
# 97034                                            English  2021.0   Jul
# 91810                                            English  2020.0   Jan
# 47746                         English,Simplified Chinese  2021.0   Jul
#
#        user_rating_all  total_review_all
# 36904              NaN               NaN
# 55274              NaN               NaN
# 97034              NaN               NaN
# 91810              NaN               NaN
# 47746              NaN               NaN

# %%
df_extract_2['recent_reviews'] = df_extract_2['recent_reviews'].str.replace(',','')
df_extract_2['user_rating_recent'] = df_extract_2['recent_reviews'].str.findall('(\d+)').str[0].astype(float)
df_extract_2['total_review_recent'] = df_extract_2['recent_reviews'].str.findall('(\d+)').str[1].astype(float)
df_extract_2 = df_extract_2.drop('recent_reviews',axis=1)
df_extract_2.sample(5)
# Out:
#                                            title       platforms  \
# 41066                              Hunt-or-Haunt         Windows
# 30348                         Soldier and Sapper         Windows
# 77491                      Afterlife Empire Demo  Windows,Mac OS
# 1959   Super Animal Royale Season 3 Starter Pack  Windows,Mac OS
# 28892                             Metal Commando         Windows
#
#       original_price                   developer                   publisher  \
# 41066      Rp 39 999                 DAONE GAMES                 DAONE GAMES
# 30348     Rp 137 698                         NaN                         NaN
# 77491      Free Demo  Autobotika,Game Nation Inc  The Fine Young Capitalists
# 1959       Rp 40 000                      Pixile                 Modus Games
# 28892       Rp 8 499              indiegames3000              indiegames3000
#
#       overall_reviews                                               tags  \
# 41066  4 user reviews  Early Access,Multiplayer,Party Game,Indie,Casu...
# 30348             NaN                                                NaN
# 77491           Mixed                              Casual,Indie,Strategy
# 1959         Positive  Action,Adventure,Free to Play,Massively Multip...
# 28892           Mixed  Singleplayer,2D,Action,Adventure,Casual,Indie,...
#
#                                                    genre        ram  \
# 41066          Action,Casual,Indie,Strategy,Early Access   4 GB RAM
# 30348                                                NaN        NaN
# 77491                              Casual,Indie,Strategy   2 GB RAM
# 1959   Action,Adventure,Casual,Free to Play,Indie,Mas...   3 GB RAM
# 28892                                              Indie   1 GB RAM
#
#                                                   rating  \
# 41066                                                NaN
# 30348                                                NaN
# 77491                                                NaN
# 1959   https://store.akamai.steamstatic.com/public/sh...
# 28892                                                NaN
#
#                                                 language    year month  \
# 41066     English,Simplified Chinese,Traditional Chinese  2022.0   Jan
# 30348                                                NaN     NaN  None
# 77491                                            English  2015.0   Aug
# 1959   English,Japanese,Korean,Russian,Simplified Chi...  2022.0   Apr
# 28892                                            English  2020.0   Nov
#
#        user_rating_all  total_review_all  user_rating_recent  \
# 41066              NaN               NaN                 NaN
# 30348              NaN               NaN                 NaN
# 77491              NaN               NaN                51.0
# 1959               NaN               NaN               100.0
# 28892              NaN               NaN                68.0
#
#        total_review_recent
# 41066                  NaN
# 30348                  NaN
# 77491                 68.0
# 1959                  34.0
# 28892                 41.0

# %% [markdown]
# #### extract `supported_language`

# %%
df_extract_3 = df_extract_2.copy()
df_extract_3['supported_language'] = df_extract_3['language'].str.split(',').apply(lambda x: len(x) if type(x) == list else x)
#df_extract_3['english_language'] = df_extract_3['language'].str.lower().str.contains('english')
df_extract_3 = df_extract_3.drop('language',axis=1)
df_extract_3.sample(5)
# Out:
#                                                     title platforms  \
# 114537  灵魂筹码 - 沉冤奈河 Soul at Stake - Drown in the Disgrace   Windows
# 51592                            Super Minesweeper attACK   Windows
# 63997                                           Bug Blast   Windows
# 42708                              Wizard Lady Soundtrack       NaN
# 38475                  Edge of Twilight – Return To Glory   Windows
#
#        original_price         developer                        publisher  \
# 114537      Rp 22 999  Chongming Studio                 Chongming Studio
# 51592        Rp 8 499           Triadne                          Triadne
# 63997            Free       Giga Grunts  DigiPen Institute of Technology
# 42708       Rp 17 499         IR Studio                        IR Studio
# 38475      Rp 115 999         FUZZYEYES                        FUZZYEYES
#
#         overall_reviews                                               tags  \
# 114537            Mixed                      RPG,Indie,Action,Gore,Violent
# 51592    2 user reviews                                       Indie,Casual
# 63997    8 user reviews  Top-Down Shooter,Action,Twin Stick Shooter,Rog...
# 42708    1 user reviews                                                NaN
# 38475   Mostly Negative                   Adventure,Action,Indie,Steampunk
#
#                          genre        ram rating    year month  \
# 114537        Action,Indie,RPG   8 GB RAM    NaN  2019.0   Jun
# 51592             Casual,Indie   8 MB RAM    NaN  2019.0   Sep
# 63997      Action,Free to Play   2 GB RAM    NaN  2020.0   Jun
# 42708                      NaN        NaN    NaN  2020.0   Apr
# 38475   Action,Adventure,Indie   4 GB RAM    NaN  2016.0   Sep
#
#         user_rating_all  total_review_all  user_rating_recent  \
# 114537              NaN               NaN                60.0
# 51592               NaN               NaN                 NaN
# 63997               NaN               NaN                 NaN
# 42708               NaN               NaN                 NaN
# 38475               NaN               NaN                37.0
#
#         total_review_recent  supported_language
# 114537                 15.0                 2.0
# 51592                   NaN                 1.0
# 63997                   NaN                 1.0
# 42708                   NaN                 NaN
# 38475                  29.0                 9.0

# %% [markdown]
# #### extract `price`

# %%
df_extract_3[df_extract_3['original_price'].str.lower().str.contains('from')==True]
# Out:
#                                          title platforms   original_price  \
# 27972                        Amnesia Fortnight       NaN  From Rp 188 997
# 95150   Hyperdimension Neptunia: The Animation       NaN  From Rp 259 197
# 110048                                  PHOBIA       NaN   From Rp 29 743
#
#                                            developer  \
# 27972   2 Player Productions,Double Fine Productions
# 95150                     IDEA FACTORY,COMPILE HEART
# 110048                         Open Sign Productions
#
#                          publisher  overall_reviews  \
# 27972                          NaN         Positive
# 95150   Idea Factory International   1 user reviews
# 110048             Open Sign Films  Mostly Positive
#
#                                                      tags genre        ram  \
# 27972        Gaming,Game Development,Documentary,Episodic   NaN   1 GB RAM
# 95150   Adventure,Action,Episodic,Anime,Comedy,Cute,Nu...   NaN   1 GB RAM
# 110048  Nudity,Gore,Violent,Sexual Content,Horror,Epis...   NaN   1 GB RAM
#
#        rating    year month  user_rating_all  total_review_all  \
# 27972     NaN  2017.0   May              NaN               NaN
# 95150     NaN  2020.0   Sep              NaN               NaN
# 110048    NaN  2018.0   Feb              NaN               NaN
#
#         user_rating_recent  total_review_recent  supported_language
# 27972                 80.0                 10.0                 1.0
# 95150                  NaN                  NaN                 4.0
# 110048                77.0                 27.0                11.0

# %%
df_price = df_extract_3.copy()
df_price['price'] = df_price['original_price'].str.lower().str.replace(r'\D','').astype(int,errors='ignore')
df_price.loc[df_price['price']=='','price'] = 0
df_price['price'] = df_price['price'].astype(float)
df_price = df_price.drop('original_price',axis=1)
df_price.sample(5)
# Out:
# C:\Users\Sony\AppData\Local\Temp/ipykernel_17952/1563624721.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_price['price'] = df_price['original_price'].str.lower().str.replace(r'\D','').astype(int,errors='ignore')
#                                                     title platforms  \
# 111518                                              HEXAD   Windows
# 17558                                      Brave Survivor   Windows
# 51387            [Revival] DOA6 Hot Summer Costume - Tina   Windows
# 40814        Banzai Escape 2 Subterranean - Maid Costumes   Windows
# 117129  LEGO® DC Super-Villains Batman: The Animated S...   Windows
#
#                                developer                   publisher  \
# 111518                          Keenmade                    Keenmade
# 17558                    Felio Stung ROG              kazakovstudios
# 51387         KOEI TECMO GAMES CO., LTD.  KOEI TECMO GAMES CO., LTD.
# 40814                          XenoAisam            Xenoaisam Studio
# 117129  TT Games,Feral Interactive (Mac)     Feral Interactive (Mac)
#
#        overall_reviews                                               tags  \
# 111518        Positive  Indie,Turn-Based Tactics,Party-Based RPG,Strat...
# 17558         Positive  Action,Dungeon Crawler,Difficult,2D Fighter,Ro...
# 51387   1 user reviews          Action,Gore,Violent,Nudity,Sexual Content
# 40814              NaN  Action,Co-op,Arcade,Shooter,Third-Person Shoot...
# 117129        Positive                                             Action
#
#                                                genre           ram  \
# 111518  Free to Play,Indie,RPG,Strategy,Early Access      2 GB RAM
# 17558                                   Action,Indie   1024 MB RAM
# 51387                                         Action      8 GB RAM
# 40814                                         Action      8 GB RAM
# 117129                                        Action      4 GB RAM
#
#                                                    rating    year month  \
# 111518                                                NaN  2021.0   Dec
# 17558                                                 NaN  2022.0   May
# 51387   https://store.akamai.steamstatic.com/public/sh...  2019.0   Nov
# 40814                                                 NaN  2021.0   Oct
# 117129  https://store.akamai.steamstatic.com/public/sh...  2019.0   Mar
#
#         user_rating_all  total_review_all  user_rating_recent  \
# 111518              NaN               NaN                82.0
# 17558               NaN               NaN                90.0
# 51387               NaN               NaN                 NaN
# 40814               NaN               NaN                 NaN
# 117129              NaN               NaN                86.0
#
#         total_review_recent  supported_language     price
# 111518                 17.0                 1.0       0.0
# 17558                  10.0                 1.0  119999.0
# 51387                   NaN                10.0   19000.0
# 40814                   NaN                 1.0   17499.0
# 117129                 23.0                13.0   39900.0

# %% [markdown]
# #### extract `rated_by_pegi`

# %%
df_pegi = df_price.copy()
df_pegi['pegi_rated'] = np.where(df_pegi['rating']=='Rating for: PEGI', 1, 0)
df_pegi['age_rating'] = df_pegi['rating'].str.replace(r'\D','')
df_pegi = df_pegi.drop('rating',axis=1)
df_pegi.sample(5)
# Out:
# C:\Users\Sony\AppData\Local\Temp/ipykernel_17952/1487083353.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_pegi['age_rating'] = df_pegi['rating'].str.replace(r'\D','')
#                                               title       platforms  \
# 4120                                 Chuzzle Deluxe  Windows,Mac OS
# 27786                                   Friendsim 2  Windows,Mac OS
# 52734         Between Two Cities - Stonemaier Games         Windows
# 114332                     Cloud Climber - Fan Pack         Windows
# 27473   最后的大法师 光明之旅(Last Archmage Journey of Light)         Windows
#
#                  developer                           publisher  \
# 4120    PopCap Games, Inc.  PopCap Games, Inc.,Electronic Arts
# 27786          Studio June                         Studio June
# 52734           DTDA Games                          DTDA Games
# 114332      Two Star Games                      Two Star Games
# 27473    Flying Star Games                   Flying Star Games
#
#        overall_reviews                                               tags  \
# 4120     Very Positive      Casual,Puzzle,Match 3,Cute,Singleplayer,Funny
# 27786         Positive  Visual Novel,Choices Matter,Multiple Endings,S...
# 52734   1 user reviews  Strategy,Board Game,Tabletop,Massively Multipl...
# 114332        Positive  Adventure,Free to Play,Indie,Casual,Puzzle,Sur...
# 27473         Positive  JRPG,CRPG,Singleplayer,Visual Novel,Turn-Based...
#
#                                        genre          ram    year month  \
# 4120                                  Casual   256 MB RAM  2006.0   Aug
# 27786             Adventure,Casual,Indie,RPG     2 GB RAM  2022.0   Apr
# 52734   Indie,Massively Multiplayer,Strategy     1 GB RAM  2021.0   Aug
# 114332   Adventure,Casual,Free to Play,Indie          NaN  2021.0   Feb
# 27473                 Adventure,RPG,Strategy     3 GB RAM  2020.0   Jul
#
#         user_rating_all  total_review_all  user_rating_recent  \
# 4120               92.0             603.0                90.0
# 27786               NaN               NaN                92.0
# 52734               NaN               NaN                 NaN
# 114332              NaN               NaN                93.0
# 27473               NaN               NaN                85.0
#
#         total_review_recent  supported_language    price  pegi_rated  \
# 4120                   10.0                 5.0  45999.0           0
# 27786                  25.0                 1.0      0.0           0
# 52734                   NaN                 1.0  24999.0           0
# 114332                 15.0                 1.0  24999.0           0
# 27473                  27.0                 2.0  52999.0           0
#
#        age_rating
# 4120          NaN
# 27786         NaN
# 52734           7
# 114332        NaN
# 27473         NaN

# %% [markdown]
# #### extract `windows`, `mac`, and `linux`

# %%
df_platform = df_pegi.copy()
df_platform['windows'] = np.where(df_platform['platforms'].str.contains('Windows',na=False), 1, 0)
df_platform['mac'] = np.where(df_platform['platforms'].str.contains('Mac OS',na=False), 1, 0)
df_platform['linux'] = np.where(df_platform['platforms'].str.contains('Linux',na=False), 1, 0)
df_platform['VR'] = np.where(df_platform['platforms'].str.contains('VR Supported',na=False), 1, 0)
df_platform = df_platform.drop('platforms',axis=1)
df_platform.sample(10)
# Out:
#                                                     title  \
# 12060                  Superbrothers: Sword & Sworcery EP
# 92577             Winter's Empty Mask - Visual novel Demo
# 113806                         State of Decay - Breakdown
# 51135                        In the Service of Mrs. Claus
# 9294            Hello Charlotte EP2: Requiem Aeternam Deo
# 6007                                             新三國 漢室復興
# 70179                                    Beneath The Deep
# 9344                      Fish Tycoon 2: Virtual Aquarium
# 85378   Fantasy Grounds - Odds & Ends, Volume 7 (Token...
# 106947  Baobabs Mausoleum Grindhouse Edition - Country...
#
#                                  developer              publisher  \
# 12060   Capybara,Superbrothers,Jim Guthrie         Capybara Games
# 92577                Eternal Night Studios  Eternal Night Studios
# 113806                         Undead Labs      Xbox Game Studios
# 51135                      Choice of Games        Choice of Games
# 9294                              etherane               etherane
# 6007                          Hermes Games           Hermes Games
# 70179                            PaperMoon              PaperMoon
# 9344                      Last Day Of Work       Last Day Of Work
# 85378                  SmiteWorks USA, LLC                    NaN
# 106947                      Celery Emblem™         Celery Emblem™
#
#         overall_reviews                                               tags  \
# 12060   Mostly Positive  Adventure,Indie,Pixel Graphics,Great Soundtrac...
# 92577          Positive  Action,Indie,Casual,Gore,Visual Novel,Violent,...
# 113806  Mostly Positive  Zombies,Action,RPG,Simulation,Survival,Open Wo...
# 51135    6 user reviews              Adventure,RPG,Indie,Casual,Text-Based
# 9294      Very Positive  RPG,2D,Horror,Psychological Horror,Anime,Cute,...
# 6007    Mostly Positive  Strategy,RPG,RTS,Historical,War,3D,Wargame,Mil...
# 70179               NaN  Strategy,Adventure,Puzzle,Horror,Psychological...
# 9344              Mixed                                         Simulation
# 85378               NaN                        RPG,Indie,Strategy,Software
# 106947   3 user reviews  Adventure,Platformer,Exploration,Action-Advent...
#
#                              genre           ram    year month  \
# 12060              Adventure,Indie      1 GB RAM  2012.0   Apr
# 92577          Action,Casual,Indie      1 GB RAM  2019.0   Mar
# 113806       Action,RPG,Simulation      2 GB RAM  2013.0   Nov
# 51135   Adventure,Casual,Indie,RPG           NaN  2019.0   Dec
# 9294           Adventure,Indie,RPG    512 MB RAM  2016.0   Nov
# 6007                  RPG,Strategy   2048 MB RAM  2022.0   Feb
# 70179               Indie,Strategy      8 GB RAM  2022.0  None
# 9344                    Simulation    512 MB RAM  2018.0   May
# 85378           Indie,RPG,Strategy      1 GB RAM  2018.0   Aug
# 106947             Adventure,Indie      2 GB RAM  2021.0   Feb
#
#         user_rating_all  ...  user_rating_recent  total_review_recent  \
# 12060               NaN  ...                78.0               1284.0
# 92577               NaN  ...               100.0                 17.0
# 113806              NaN  ...                76.0                145.0
# 51135               NaN  ...                 NaN                  NaN
# 9294               97.0  ...               100.0                 36.0
# 6007                NaN  ...                72.0                 29.0
# 70179               NaN  ...                 NaN                  NaN
# 9344                NaN  ...                56.0                185.0
# 85378               NaN  ...                 NaN                  NaN
# 106947              NaN  ...                 NaN                  NaN
#
#         supported_language     price  pegi_rated  age_rating windows  mac  \
# 12060                  2.0   59999.0           0         NaN       1    1
# 92577                  2.0       0.0           0         NaN       1    1
# 113806                 5.0   59999.0           0          18       1    0
# 51135                  1.0   32999.0           0         NaN       1    1
# 9294                   8.0       NaN           0          15       1    0
# 6007                   2.0       0.0           0          16       1    0
# 70179                  1.0       NaN           0         NaN       1    0
# 9344                   1.0       0.0           0         NaN       1    1
# 85378                  1.0   64999.0           0         NaN       1    1
# 106947                 4.0  102999.0           0         NaN       1    1
#
#         linux  VR
# 12060       1   0
# 92577       1   0
# 113806      0   0
# 51135       1   0
# 9294        0   0
# 6007        0   0
# 70179       0   0
# 9344        0   0
# 85378       0   0
# 106947      0   0
#
# [10 rows x 21 columns]

# %% [markdown]
# #### remap `ram`

# %%
df_ram = df_platform.copy()
df_ram.loc[df_ram['ram'].str.lower().str.contains('9 gb', na=False),'ram'] = '9 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('8 gb|8000 mb|８ gb|8gb|8.0 gb|8\+ gb', na=False),'ram'] = '8 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('7 gb', na=False),'ram'] = '7 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('6 gb|6000 mb|６ gb', na=False),'ram'] = '6 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('5 gb|5000 mb', na=False),'ram'] = '5 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('4 gb|4096 mb|4000 mb|4gb|４ gb|4.00 gb|4g|4 ram gb', na=False),'ram'] = '4 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('3 gb|3000 mb|3 go mb|3gb', na=False),'ram'] = '3 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('2 gb|2048|2000 mb|2gb|1536 mb|2.0 gb|2000 gb|２ gb|1.5gb|2.0gb|2g', na=False),'ram'] = '2 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('1 gb|1024|1000 mb|1gb|800 mb|750 mb|1280 mb|700 mb|900 mb|１ gb|1\+', na=False),'ram'] = '1 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('512|500 mb|400 mb|512mb|600 mb|597 mb|320 mb|420 mb|500mb|349 mb', na=False),'ram'] = '512 MB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('256 gb|200 mb|300 mb|250 mb|256mb|220 mb|256 ram', na=False),'ram'] = '256 MB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('16.0 gb', na=False),'ram'] = '16 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('12.00 gb', na=False),'ram'] = '12 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('10 gb', na=False),'ram'] = '10 GB'
df_ram.loc[df_ram['ram'].str.lower().str.contains('128 mb|64m|70 mb|100 mb|150 mb|16 mb|8 mb|2 mb|1 mb|4 mb|50 mb|3 mb|6 mb|10 mb|128mb|80 mb|4 ram mb|30 mb|40 mb|25 mb|5 mb|120 mb|64 mb|90 mb|60 mb|95 mb|65 mb|64mb|16mb|100以上|32mb|97 mb|20 mb|99 mb|4mb|69 mb|59 mb', na=False),'ram'] = '<128 MB'
df_ram.loc[~df_ram['ram'].str.lower().str.contains('16 gb|12 gb|10 gb|9 gb|8 gb|7 gb|6 gb|5 gb|4 gb|3 gb|2 gb|1 gb|512 mb|256 mb|<128 mb', na=False),'ram'] = 'Unknown'
df_ram['ram'].value_counts()
# Out:
# 4 GB       22820
# 2 GB       20294
# Unknown    18386
# 1 GB       13700
# <128 MB    13624
# 8 GB       10864
# 6 GB        3124
# 3 GB         963
# 5 GB         158
# 10 GB         30
# 9 GB           7
# 7 GB           5
# 12 GB          1
# Name: ram, dtype: int64

# %%
df_ram.sample(10)
# Out:
#                                           title  \
# 121335  Euro Truck Simulator 2 - FH Tuning Pack
# 59291                               Dark Empire
# 21047                   Dark Fall 2: Lights Out
# 75482                    Panzer Arena: Prologue
# 79328          Sid Meier's Civilization VI Demo
# 67373                       Grammarian Ltd Demo
# 90072                           We Are Screwed!
# 51285                   Connectome:Pain Control
# 4703    Guild of Dungeoneering Ultimate Edition
# 51065                         Breakout Invaders
#
#                                       developer                     publisher  \
# 121335                             SCS Software                  SCS Software
# 59291                                       Jan                   Jan Company
# 21047                             Darkling Room                    THQ Nordic
# 75482                          Osman Tsjardiwal              Osman Tsjardiwal
# 79328   Firaxis Games,Aspyr (Mac),Aspyr (Linux)  2K,Aspyr (Mac),Aspyr (Linux)
# 67373                       Algorocks,Simpleton                     Algorocks
# 90072                                  Rarebyte                      Rarebyte
# 51285                        Melancholia Studio            Melancholia Studio
# 4703                                 Gambrinous                    Gambrinous
# 51065                           DreamsSoftGames               DreamsSoftGames
#
#         overall_reviews                                               tags  \
# 121335    Very Positive                      Simulation,Indie,Singleplayer
# 59291    1 user reviews                            Casual,Simulation,Indie
# 21047   Mostly Positive  Adventure,Point & Click,Horror,Puzzle,Mystery,...
# 75482               NaN  Action,Sports,Arcade,eSports,Shooter,Arena Sho...
# 79328     Very Positive  Strategy,Turn-Based Strategy,Historical,Multip...
# 67373          Positive  Simulation,Education,Life Sim,Management,Casua...
# 90072               NaN  Exploration,Roguelite,3D,Funny,Action,Action-A...
# 51285    8 user reviews  Action,Indie,Fighting,Robots,Great Soundtrack,...
# 4703    Mostly Positive  Roguelike Deckbuilder,Roguelike,Deckbuilding,R...
# 51065    6 user reviews                                Indie,Casual,Action
#
#                                     genre      ram    year month  \
# 121335                   Indie,Simulation     4 GB  2020.0   Jun
# 59291             Casual,Indie,Simulation     1 GB  2017.0   Dec
# 21047                           Adventure  <128 MB  2013.0   Dec
# 75482          Action,Indie,Racing,Sports     4 GB  2022.0   Jul
# 79328                            Strategy     4 GB  2017.0   Mar
# 67373   Adventure,Casual,Indie,Simulation     3 GB  2022.0   Mar
# 90072       Action,Adventure,Casual,Indie     2 GB  2022.0  None
# 51285                        Action,Indie     4 GB  2019.0   Jan
# 4703                            Indie,RPG     2 GB  2015.0   Jul
# 51065                 Action,Casual,Indie     1 GB  2015.0   Apr
#
#         user_rating_all  ...  user_rating_recent  total_review_recent  \
# 121335              NaN  ...                86.0                589.0
# 59291               NaN  ...                 NaN                  NaN
# 21047               NaN  ...                70.0                 62.0
# 75482               NaN  ...                 NaN                  NaN
# 79328              83.0  ...                85.0               2062.0
# 67373               NaN  ...                90.0                 10.0
# 90072               NaN  ...                 NaN                  NaN
# 51285               NaN  ...                 NaN                  NaN
# 4703                NaN  ...                76.0               1565.0
# 51065               NaN  ...                 NaN                  NaN
#
#         supported_language     price  pegi_rated  age_rating windows  mac  \
# 121335                24.0   35900.0           0           3       1    1
# 59291                  1.0   30999.0           0         NaN       1    0
# 21047                  1.0   45999.0           0           7       1    0
# 75482                  1.0       NaN           0         NaN       1    0
# 79328                 12.0       0.0           0          12       1    0
# 67373                  1.0       0.0           0         NaN       1    0
# 90072                  1.0       NaN           0         NaN       1    1
# 51285                  4.0   59999.0           0         NaN       1    0
# 4703                   5.0  108999.0           0         NaN       1    1
# 51065                  3.0   32999.0           0         NaN       1    0
#
#         linux  VR
# 121335      1   0
# 59291       0   0
# 21047       0   0
# 75482       0   0
# 79328       0   0
# 67373       0   0
# 90072       0   0
# 51285       0   0
# 4703        0   0
# 51065       0   0
#
# [10 rows x 21 columns]

# %% [markdown]
# #### remap `overall_reviews`

# %%
df_or = df_ram.copy()
df_or.loc[~df_or['overall_reviews'].str.contains('Positive|Negative|Very|Overwhelmingly|Mixed|Mostly', na=False),'overall_reviews'] = '<10 reviews'
df_or['overall_reviews'].value_counts()
# Out:
# <10 reviews                62387
# Very Positive              11779
# Mixed                      10099
# Positive                   10025
# Mostly Positive             7321
# Mostly Negative             1586
# Overwhelmingly Positive      461
# Negative                     245
# Very Negative                 64
# Overwhelmingly Negative        9
# Name: overall_reviews, dtype: int64

# %%
df_or.sample(5)
# Out:
#                                                    title  \
# 78630    Fantasy Grounds - Deadlands Reloaded: The Flood
# 60734                                        The Message
# 41220        The Marauder Chronicles: Curse Over Valdria
# 38211  DYNASTY WARRIORS 9 Empires - Unisex Custom Cun...
# 84144     Heroine Anthem Zero 2：Colorful Feather Pack IV
#
#                         developer                   publisher overall_reviews  \
# 78630         SmiteWorks USA, LLC                         NaN     <10 reviews
# 60734                 Dream Games                 Dream Games     <10 reviews
# 41220        Mambo Dancing Shrimp                    Gamuzumi     <10 reviews
# 38211  KOEI TECMO GAMES CO., LTD.  KOEI TECMO GAMES CO., LTD.     <10 reviews
# 84144          WindThunder Studio                Skywalker HK     <10 reviews
#
#                                                     tags  \
# 78630  RPG,Indie,Strategy,Utilities,Western,Turn-Base...
# 60734  Early Access,Action,Violent,Gore,Shooter,Beat ...
# 41220  Adventure,Sexual Content,Nudity,Visual Novel,F...
# 38211                         Strategy,Action,Simulation
# 84144                               Action,Adventure,RPG
#
#                             genre      ram    year month  user_rating_all  \
# 78630          Indie,RPG,Strategy     1 GB  2016.0   Jun              NaN
# 60734   Action,Indie,Early Access     8 GB  2020.0   Dec              NaN
# 41220                   Adventure  <128 MB  2021.0   Oct              NaN
# 38211  Action,Simulation,Strategy     6 GB  2022.0   Jan              NaN
# 84144        Action,Adventure,RPG     6 GB  2022.0   Feb              NaN
#
#        ...  user_rating_recent  total_review_recent  supported_language  \
# 78630  ...                 NaN                  NaN                 1.0
# 60734  ...                 NaN                  NaN                 1.0
# 41220  ...                 NaN                  NaN                 3.0
# 38211  ...                 NaN                  NaN                 9.0
# 84144  ...                 NaN                  NaN                 4.0
#
#          price  pegi_rated  age_rating windows  mac  linux  VR
# 78630  95999.0           0         NaN       1    0      0   0
# 60734  95999.0           0         NaN       1    0      0   0
# 41220  39999.0           0         NaN       1    0      0   0
# 38211  57000.0           0          12       1    0      0   0
# 84144  24999.0           0         NaN       1    0      0   0
#
# [5 rows x 21 columns]

# %% [markdown]
# #### reformat and remap `tags`

# %%
def to_1D(series): #list feature function
 return pd.Series([x for _list in series for x in _list])

# %%
df_tags = df_or.copy()
df_tags.loc[df_tags['tags'].isna()==True,'tags'] = 'No Tags'
df_tags['tags'] = df_tags['tags'].str.split(',')
#df_tags['tags'] = df_tags['tags'].replace(',', '","')
#df_tags['tags'] = '["' + df_tags['tags'] + '"]'
df_tags.sample(10)
# Out:
#                                                 title  \
# 56044                                    INSPACE 2980
# 96793        Tiger Fighter 1931 Tora!Tora!Tora! MP086
# 121851                        Total War: WARHAMMER II
# 76350                                    Super Catboy
# 104839              Journey of Greed - Male Skin Pack
# 29311                                            佣兵战歌
# 16576                    Altwaldheim: Town in Turmoil
# 93067                                   Fay's Factory
# 741                           RISK: Global Domination
# 62391   Grass Cutters Academy - 50,000 Upgrade Points
#
#                                                 developer  \
# 56044                                             R_Games
# 96793                                         TigerQiuQiu
# 121851  CREATIVE ASSEMBLY,Feral Interactive (Mac),Fera...
# 76350                                           Pixelpogo
# 104839                                         Dird Games
# 29311                                              酷呐网络科技
# 16576                                    Ascendancy Games
# 93067                                        egor dorogov
# 741                                            SMG Studio
# 62391                                          ColloseusX
#
#                                                 publisher overall_reviews  \
# 56044                                             R_Games     <10 reviews
# 96793                                         TigerQiuQiu     <10 reviews
# 121851  SEGA,Feral Interactive (Mac),Feral Interactive...   Very Positive
# 76350                              Assemble Entertainment     <10 reviews
# 104839                                  X.D. Network Inc.     <10 reviews
# 29311                                              酷呐网络科技           Mixed
# 16576                                    Ascendancy Games        Positive
# 93067                                        egor dorogov     <10 reviews
# 741                                            SMG Studio   Very Positive
# 62391                                  Phat Phrog Studios     <10 reviews
#
#                                                      tags  \
# 56044   [Shoot 'Em Up, Bullet Hell, Space, Old School,...
# 96793   [Action, Indie, Casual, Old School, Pixel Grap...
# 121851  [Strategy, Fantasy, Turn-Based Strategy, RTS, ...
# 76350   [Precision Platformer, Pixel Graphics, Action-...
# 104839  [Strategy, Indie, Card Game, Board Game, Tradi...
# 29311   [Strategy, Adventure, RPG, Strategy RPG, Rogue...
# 16576   [City Builder, Roguelite, Building, Management...
# 93067   [RPG, Turn-Based Strategy, Capitalism, Deckbui...
# 741     [Free to Play, Board Game, Multiplayer, Strate...
# 62391                       [Free to Play, Indie, Casual]
#
#                                       genre      ram    year month  \
# 56044                Action,Adventure,Indie     2 GB  2018.0   Oct
# 96793                   Action,Casual,Indie     4 GB  2021.0   Sep
# 121851                      Action,Strategy     5 GB  2017.0   Sep
# 76350                Action,Adventure,Indie     4 GB  2022.0  None
# 104839                       Indie,Strategy     2 GB  2020.0   Mar
# 29311   Adventure,Casual,Indie,RPG,Strategy     8 GB  2020.0   Jan
# 16576      Casual,Indie,Simulation,Strategy  <128 MB  2020.0   Aug
# 93067                    Indie,RPG,Strategy     4 GB  2022.0  None
# 741            Casual,Free to Play,Strategy     2 GB  2020.0   Feb
# 62391             Casual,Free to Play,Indie  <128 MB  2021.0   Feb
#
#         user_rating_all  ...  user_rating_recent  total_review_recent  \
# 56044               NaN  ...                 NaN                  NaN
# 96793               NaN  ...                 NaN                  NaN
# 121851             93.0  ...                89.0                573.0
# 76350               NaN  ...                 NaN                  NaN
# 104839              NaN  ...                 NaN                  NaN
# 29311               NaN  ...                47.0                 42.0
# 16576               NaN  ...                91.0                 12.0
# 93067               NaN  ...                 NaN                  NaN
# 741                83.0  ...                81.0                541.0
# 62391               NaN  ...                 NaN                  NaN
#
#         supported_language     price  pegi_rated  age_rating windows  mac  \
# 56044                  2.0   24999.0           0         NaN       1    1
# 96793                  1.0    8499.0           0         NaN       1    0
# 121851                13.0  540999.0           0          16       1    1
# 76350                 10.0       NaN           0         NaN       1    1
# 104839                 3.0   24999.0           0           3       1    1
# 29311                  2.0   64999.0           0         NaN       1    0
# 16576                  2.0   69999.0           0         NaN       1    0
# 93067                  1.0       NaN           0         NaN       1    0
# 741                    9.0       0.0           0           7       1    1
# 62391                  1.0   59999.0           0         NaN       1    0
#
#         linux  VR
# 56044       0   0
# 96793       0   0
# 121851      1   0
# 76350       0   0
# 104839      0   0
# 29311       0   0
# 16576       0   0
# 93067       0   0
# 741         0   0
# 62391       0   0
#
# [10 rows x 21 columns]

# %%
to_1D(df_tags['tags']).value_counts().head(50)
# Out:
# Indie                 54882
# Action                41227
# Casual                35092
# Adventure             34938
# Singleplayer          34624
# Simulation            22556
# Strategy              21265
# RPG                   20146
# 2D                    18546
# Atmospheric           12636
# Puzzle                11747
# Pixel Graphics        10670
# 3D                    10459
# Story Rich            10377
# Fantasy                9994
# Colorful               9534
# Multiplayer            9030
# Early Access           8974
# Exploration            8696
# Cute                   8223
# First-Person           8047
# Arcade                 7827
# No Tags                7770
# Funny                  7176
# Shooter                7117
# Free to Play           7114
# Sci-fi                 7022
# Platformer             6859
# Retro                  6745
# Family Friendly        6612
# Anime                  6372
# Horror                 6243
# Relaxing               6208
# Action-Adventure       6132
# Violent                6071
# Difficult              5764
# Female Protagonist     5556
# VR                     5372
# Open World             5234
# Great Soundtrack       5221
# Third Person           5175
# Gore                   5160
# Survival               4836
# Sports                 4727
# Stylized               4726
# Co-op                  4711
# Top-Down               4567
# Comedy                 4414
# Visual Novel           4369
# Combat                 4345
# dtype: int64

# %% [markdown]
# #### reformat and remap `genre`

# %%
df_genre = df_tags.copy()
df_genre.loc[df_genre['genre'].isna()==True,'genre'] = 'No Genre'
df_genre['genre'] = df_genre['genre'].str.split(',')
#df_tags['tags'] = df_tags['tags'].replace(',', '","')
#df_tags['tags'] = '["' + df_tags['tags'] + '"]'
df_genre.sample(10)
# Out:
#                                                     title  \
# 47192                   OASE - Other Age Second Encounter
# 36564                                  The Binding of YOU
# 30070                              Soccer Pinball Thrills
# 2492                             The Sims 3 - Movie Stuff
# 67387                             Song of Iron Soundtrack
# 111739                                      He Will Shoot
# 77559   Fantasy Grounds - A04: Forest for the Trees (P...
# 900                                              NBA 2K21
# 103524                            DOA6 Rig Deluxe Costume
# 10495                                 Valentine's Day Set
#
#                                     developer  \
# 47192                               Zeiva Inc
# 36564                       StarSystemStudios
# 30070                    Fancy Bytes, Reactor
# 2492                          The Sims Studio
# 67387                           Resting Relic
# 111739                             Boom Games
# 77559                     SmiteWorks USA, LLC
# 900                           Visual Concepts
# 103524             KOEI TECMO GAMES CO., LTD.
# 10495   Team NINJA,KOEI TECMO GAMES CO., LTD.
#
#                                publisher  overall_reviews  \
# 47192                          Zeiva Inc      <10 reviews
# 36564                  StarSystemStudios  Mostly Negative
# 30070   United Independent Entertainment            Mixed
# 2492                                 NaN            Mixed
# 67387                                NaN      <10 reviews
# 111739                        Boom Games            Mixed
# 77559                                NaN      <10 reviews
# 900                                   2K            Mixed
# 103524        KOEI TECMO GAMES CO., LTD.      <10 reviews
# 10495                                NaN         Positive
#
#                                                      tags  \
# 47192   [Adventure, Indie, Casual, Simulation, Visual ...
# 36564                   [Casual, Action, Indie, Strategy]
# 30070               [Casual, Simulation, Sports, Pinball]
# 2492                                         [Simulation]
# 67387                                           [No Tags]
# 111739  [Zombies, Post-apocalyptic, Arena Shooter, Thi...
# 77559   [RPG, Indie, Strategy, Fantasy, Medieval, Part...
# 900     [Basketball, Sports, Simulation, Character Cus...
# 103524    [Action, Gore, Violent, Nudity, Sexual Content]
# 10495                                            [Action]
#
#                                               genre      ram    year month  \
# 47192        [Adventure, Casual, Indie, Simulation]     2 GB  2015.0   Sep
# 36564             [Action, Casual, Indie, Strategy]     2 GB  2019.0   Sep
# 30070                  [Casual, Simulation, Sports]     2 GB  2015.0   Jun
# 2492                                   [Simulation]     5 GB  2013.0   Sep
# 67387                                    [No Genre]  Unknown  2021.0   Sep
# 111739  [Action, Adventure, Indie, RPG, Simulation]     4 GB  2021.0   Dec
# 77559                        [Indie, RPG, Strategy]     1 GB  2016.0   Jul
# 900                            [Simulation, Sports]     4 GB  2020.0   Sep
# 103524                                     [Action]     8 GB  2019.0   Aug
# 10495                                      [Action]     2 GB  2016.0   Feb
#
#         user_rating_all  ...  user_rating_recent  total_review_recent  \
# 47192               NaN  ...                 NaN                  NaN
# 36564               NaN  ...                25.0                 12.0
# 30070               NaN  ...                40.0                 10.0
# 2492                NaN  ...                63.0                 22.0
# 67387               NaN  ...                 NaN                  NaN
# 111739              NaN  ...                45.0                 22.0
# 77559               NaN  ...                 NaN                  NaN
# 900                42.0  ...                51.0                 99.0
# 103524              NaN  ...                 NaN                  NaN
# 10495               NaN  ...               100.0                 12.0
#
#         supported_language     price  pegi_rated  age_rating windows  mac  \
# 47192                  1.0  135999.0           0         NaN       1    0
# 36564                  1.0    8499.0           0         NaN       1    0
# 30070                  2.0   35999.0           0         NaN       1    0
# 2492                  17.0  282000.0           0          12       1    0
# 67387                  NaN   52999.0           0         NaN       0    0
# 111739                 1.0   17499.0           0         NaN       1    0
# 77559                  1.0   48999.0           0         NaN       1    0
# 900                    9.0  699000.0           0           3       1    0
# 103524                10.0   19000.0           0          16       1    0
# 10495                  8.0  159999.0           0          16       1    0
#
#         linux  VR
# 47192       0   0
# 36564       0   0
# 30070       0   0
# 2492        0   0
# 67387       0   0
# 111739      0   0
# 77559       0   0
# 900         0   0
# 103524      0   0
# 10495       0   0
#
# [10 rows x 21 columns]

# %%
to_1D(df_genre['genre']).value_counts()
# Out:
# Indie                    60589
# Action                   39905
# Casual                   32763
# Adventure                32583
# Simulation               21664
# Strategy                 20129
# RPG                      19297
# No Genre                  8359
# Early Access              7393
# Free to Play              6726
# Sports                    4460
# Racing                    3738
# Massively Multiplayer     2844
# Design & Illustration     2020
# Web Publishing            1613
# Utilities                 1184
# Animation & Modeling       620
# Education                  549
# Software Training          387
# Video Production           384
# Game Development           360
# Audio Production           310
# Photo Editing              263
# Accounting                  19
# Movie                        3
# Documentary                  1
# Episodic                     1
# Short                        1
# Tutorial                     1
# 360 Video                    1
# dtype: int64

# %% [markdown]
# #### reformat and remap `developer`

# %%
df_dev = df_genre.copy()
df_dev.loc[df_dev['developer'].isna()==True,'developer'] = 'Unknown'
df_dev['developer'] = df_dev['developer'].str.split(',')
#df_tags['tags'] = df_tags['tags'].replace(',', '","')
#df_tags['tags'] = '["' + df_tags['tags'] + '"]'
df_dev.sample(10)
# Out:
#                                                     title  \
# 21987                                     Ebi-Hime Bundle
# 54756                                              unBorn
# 54419                           ELMIA Original Soundtrack
# 9305                                       Super Mustache
# 8498    RISK: Global Domination - Countries & Continen...
# 116206                                            Intrude
# 8816       Euro Truck Simulator 2 - Swiss Paint Jobs Pack
# 56630                               送小鸡回家 sendchickenhome
# 114075                                            Event-D
# 4216                                    9-nine-:Episode 1
#
#                    developer              publisher  overall_reviews  \
# 21987              [Unknown]                    NaN      <10 reviews
# 54756      [Frenetic Gaming]        Frenetic Gaming      <10 reviews
# 54419              [AECRNIA]       AnelaGamesStudio      <10 reviews
# 9305           [Redro Games]  Back To Basics Gaming  Mostly Positive
# 8498            [SMG Studio]                    NaN         Positive
# 116206        [Michal Kruba]           Michal Kruba    Very Positive
# 8816          [SCS Software]           SCS Software         Positive
# 56630            [独自一人游戏工作室]                    念如饺      <10 reviews
# 114075  [Freedintale Studio]     Freedintale Studio         Positive
# 4216               [PALETTE]          Sekai Project    Very Positive
#
#                                                      tags  \
# 21987                                           [No Tags]
# 54756                         [Indie, Casual, Simulation]
# 54419   [Action, Indie, Casual, Fantasy, Story Rich, G...
# 9305    [Indie, Adventure, Action, Platformer, Casual,...
# 8498                     [Strategy, Free to Play, Casual]
# 116206  [Action, Indie, FPS, Shooter, Retro, Pixel Gra...
# 8816                                  [Simulation, Indie]
# 56630          [Indie, Casual, Action, Adventure, Puzzle]
# 114075  [Adventure, Visual Novel, Sci-fi, Futuristic, ...
# 4216    [Visual Novel, Anime, Sexual Content, Nudity, ...
#
#                                      genre      ram    year month  \
# 21987                           [No Genre]  Unknown     NaN  None
# 54756          [Casual, Indie, Simulation]     2 GB  2018.0   Jul
# 54419              [Action, Casual, Indie]  Unknown  2017.0   Dec
# 9305    [Action, Adventure, Casual, Indie]  <128 MB  2016.0   Jan
# 8498      [Casual, Free to Play, Strategy]  Unknown  2020.0   Sep
# 116206                     [Action, Indie]     1 GB  2016.0   Aug
# 8816                   [Indie, Simulation]     4 GB  2016.0   Jul
# 56630   [Action, Adventure, Casual, Indie]     8 GB  2020.0   Apr
# 114075                         [Adventure]     2 GB  2018.0   Dec
# 4216                  [Casual, Simulation]     4 GB  2019.0   Jan
#
#         user_rating_all  ...  user_rating_recent  total_review_recent  \
# 21987               NaN  ...                 NaN                  NaN
# 54756               NaN  ...                 NaN                  NaN
# 54419               NaN  ...                 NaN                  NaN
# 9305                NaN  ...                74.0                276.0
# 8498                NaN  ...                80.0                 10.0
# 116206              NaN  ...                84.0                176.0
# 8816                NaN  ...                95.0                 42.0
# 56630               NaN  ...                 NaN                  NaN
# 114075              NaN  ...                81.0                 22.0
# 4216               95.0  ...                92.0                 13.0
#
#         supported_language      price  pegi_rated  age_rating windows  mac  \
# 21987                  NaN  1034380.0           0         NaN       1    0
# 54756                  1.0     8499.0           0         NaN       1    0
# 54419                  2.0    59999.0           0         NaN       1    0
# 9305                   1.0     8499.0           0         NaN       1    0
# 8498                   9.0    32999.0           0           7       1    1
# 116206                 1.0    35999.0           0         NaN       1    0
# 8816                  23.0     9200.0           0           3       1    1
# 56630                  2.0     8499.0           0         NaN       1    0
# 114075                 2.0    39999.0           0         NaN       1    0
# 4216                   3.0   143942.0           0         NaN       1    0
#
#         linux  VR
# 21987       1   0
# 54756       0   0
# 54419       0   0
# 9305        0   0
# 8498        0   0
# 116206      0   0
# 8816        1   0
# 56630       0   0
# 114075      0   0
# 4216        0   0
#
# [10 rows x 21 columns]

# %%
to_1D(df_dev['developer']).value_counts().head(50)
# Out:
# Unknown                           6112
#  LLC                              2463
# SmiteWorks USA                    1965
#  LTD.                             1831
# KOEI TECMO GAMES CO.              1647
# Ubisoft - San Francisco           1517
# TigerQiuQiu                       1443
#  Ltd.                              830
#  Inc.                              667
# CAPCOM Co.                         506
# Dovetail Games                     381
# N3V Games                          335
# Feral Interactive (Mac)            307
# Nihon Falcom                       272
# Choice of Games                    253
# Feral Interactive (Linux)          240
# Idea Factory                       225
# Square Enix                        223
# Milestone S.r.l.                   213
#  Inc                               210
# Tamsoft                            205
# Inc.                               203
# Paradox Development Studio         200
# Arc System Works                   175
# Gotcha Gotcha Games                168
# Creobit                            158
# Rebellion                          155
# Hosted Games                       152
# Harmonix Music Systems             147
# Compile Heart                      146
# Capcom                             146
# ColloseusX                         139
# Ronimo Games                       131
# Relic Entertainment                130
# SCS Software                       129
# Boogygames Studios                 127
# Laush Dmitriy Sergeevich           125
# ILCA                               124
# Aspyr (Mac)                        112
# Joel Steudler                      111
# TAITO CORP.                        108
# Ltd.                               107
# Beat Games                         104
# Marvelous Inc.                     102
# Flat Cat Games                     102
# Stegalosaurus Game Development     100
# Gearbox Software                    99
# Sokpop Collective                   98
# Codename Entertainment Inc.         96
# TK.Projects                         96
# dtype: int64

# %% [markdown]
# #### reformat and remap `publisher`

# %%
df_pub = df_dev.copy()
df_pub.loc[df_pub['publisher'].isna()==True,'publisher'] = 'Unknown'
df_pub['publisher'] = df_pub['publisher'].str.split(',')
df_pub.sample(10)
# Out:
#                                                     title  \
# 21106                                   Animal and Farmer
# 37843   Bridge to Another World: Christmas Flight Coll...
# 102293                                    Legion of Scorn
# 56987                                          CADE PRIME
# 7899                                  LOGistICAL 3: Earth
# 26773                         Astronaut: The Moon Eclipse
# 51444                                Red Algorithm - Book
# 76576             Call of Duty®: Ghosts - Space Cats Pack
# 80014                                             Hermodr
# 54397                                    Bubbles & Pearls
#
#                            developer                     publisher  \
# 21106                      [Unknown]                     [Unknown]
# 37843                 [Friendly Fox]              [Big Fish Games]
# 102293  [Phoenix Resurrection Games]  [Phoenix Resurrection Games]
# 56987                [Archor Wright]                [Archor Games]
# 7899                        [Sacada]                      [Sacada]
# 26773           [AppChu Indie Games]          [AppChu Indie Games]
# 51444               [Eugene Andreev]              [Eugene Andreev]
# 76576                [Infinity Ward]                  [Activision]
# 80014                  [Regday NULL]                 [Regday NULL]
# 54397              [Hot Cocoa Games]             [Hot Cocoa Games]
#
#        overall_reviews                                               tags  \
# 21106      <10 reviews                                          [No Tags]
# 37843      <10 reviews  [Hidden Object, Puzzle, Point & Click, Female ...
# 102293     <10 reviews  [Indie, Retro, Top-Down Shooter, Twin Stick Sh...
# 56987      <10 reviews  [Casual, Puzzle, Puzzle Platformer, 3D, Parkou...
# 7899     Very Positive  [Strategy, Indie, Casual, Puzzle, Resource Man...
# 26773         Positive                        [Action, Casual, Indie, 2D]
# 51444      <10 reviews                 [Action, RPG, Indie, Free to Play]
# 76576      <10 reviews                                           [Action]
# 80014      <10 reviews  [Action, Indie, Gore, Violent, Retro, FPS, Pix...
# 54397      <10 reviews  [Sports, Exploration, Immersive Sim, 3D, 3D Vi...
#
#                                genre      ram    year month  user_rating_all  \
# 21106                     [No Genre]  Unknown     NaN  None              NaN
# 37843            [Adventure, Casual]     1 GB  2022.0   Jan              NaN
# 102293                       [Indie]     2 GB  2019.0   May              NaN
# 56987                       [Casual]  Unknown  2021.0   Sep              NaN
# 7899       [Casual, Indie, Strategy]     4 GB  2020.0   Jul              NaN
# 26773        [Action, Casual, Indie]  <128 MB  2018.0   Dec              NaN
# 51444           [Action, Indie, RPG]  <128 MB  2021.0   Oct              NaN
# 76576                       [Action]     6 GB  2014.0   Mar              NaN
# 80014                [Action, Indie]     2 GB     NaN  None              NaN
# 54397   [Casual, Simulation, Sports]     4 GB  2022.0   Mar              NaN
#
#         ...  user_rating_recent  total_review_recent  supported_language  \
# 21106   ...                 NaN                  NaN                 NaN
# 37843   ...                 NaN                  NaN                 1.0
# 102293  ...                 NaN                  NaN                 1.0
# 56987   ...                 NaN                  NaN                 1.0
# 7899    ...                85.0                 92.0                10.0
# 26773   ...               100.0                 12.0                27.0
# 51444   ...                 NaN                  NaN                 2.0
# 76576   ...                 NaN                  NaN                 5.0
# 80014   ...                 NaN                  NaN                 2.0
# 54397   ...                 NaN                  NaN                 1.0
#
#            price  pegi_rated  age_rating windows  mac  linux  VR
# 21106   184498.0           0         NaN       1    0      0   0
# 37843    89999.0           0         NaN       1    0      0   0
# 102293    8499.0           0         NaN       1    0      0   0
# 56987     8499.0           0         NaN       1    0      0   0
# 7899    169999.0           0         NaN       1    0      0   0
# 26773    17499.0           0         NaN       1    0      0   0
# 51444    17499.0           0         NaN       1    0      0   0
# 76576    18999.0           0          16       1    0      0   0
# 80014        NaN           0         NaN       1    0      1   0
# 54397    39999.0           0         NaN       1    0      0   1
#
# [10 rows x 21 columns]

# %%
to_1D(df_pub['publisher']).value_counts().head(50)
# Out:
# Unknown                       14772
#  LTD.                          1517
# Degica                         1509
# TigerQiuQiu                    1443
# KOEI TECMO GAMES CO.           1385
#  Inc.                          1094
#  Ltd.                           769
# Dovetail Games - Trains         561
# BANDAI NAMCO Entertainment      531
#  LLC                            528
# CAPCOM Co.                      495
# Paradox Interactive             458
# SEGA                            456
# Square Enix                     442
# Big Fish Games                  405
# Ubisoft                         365
# Electronic Arts                 347
# N3V Games                       347
# XSEED Games                     341
# Marvelous USA                   334
# THQ Nordic                      318
# D3 PUBLISHER                    315
# Feral Interactive (Mac)         284
# Choice of Games                 251
# 2K                              249
# PlayWay S.A.                    241
# Slitherine Ltd.                 236
# Dovetail Games - Flight         230
# NIS America                     229
# Feral Interactive (Linux)       222
# Idea Factory International      219
# Plug In Digital                 218
# Sekai Project                   215
# 8floor                          214
# Milestone S.r.l.                208
# Aerosoft GmbH                   206
# Dovetail Games                  188
# Devolver Digital                181
# PQube                           179
# Nacon                           177
# 1C Entertainment                174
# PLAYISM                         174
# Xbox Game Studios               173
# Rebellion                       171
# Daedalic Entertainment          171
# Focus Entertainment             166
# Capcom                          159
# Strategy First                  158
# Hosted Games                    152
# Activision                      146
# dtype: int64

# %% [markdown]
# ## data understanding

# %%
pd.options.display.max_columns=None

# %%
df_final = df_pub.copy()
df_final.sample(5)
# Out:
#                              title                 developer  \
# 5733      Craft The World - Heroes   [Dekovir Entertainment]
# 71754     Citizens: Far Lands Demo          [Redkar Limited]
# 8784   HELLDIVERS™ - Vehicles Pack  [Arrowhead Game Studios]
# 77128                Cube Conflict              [Jean Onche]
# 11582              Distant Space 2              [PixelMouse]
#
#                               publisher  overall_reviews  \
# 5733                          [Unknown]  Mostly Positive
# 71754  [Redkar Limited, Hawthorn Games]      <10 reviews
# 8784               [PlayStation PC LLC]    Very Positive
# 77128                      [Jean Onche]      <10 reviews
# 11582                      [PixelMouse]    Very Positive
#
#                                                     tags  \
# 5733                  [Strategy, RPG, Indie, Simulation]
# 71754  [Resource Management, Minimalist, City Builder...
# 8784                                            [Action]
# 77128  [Early Access, FPS, Fighting, Shooter, Experim...
# 11582                 [Action, Adventure, Indie, Casual]
#
#                                              genre   ram    year month  \
# 5733            [Indie, RPG, Simulation, Strategy]  1 GB  2020.0   Jun
# 71754                       [Simulation, Strategy]  4 GB  2021.0   Sep
# 8784                                      [Action]  4 GB  2015.0   Dec
# 77128  [Action, Free to Play, Indie, Early Access]  2 GB  2022.0   Jul
# 11582           [Action, Adventure, Casual, Indie]  2 GB  2017.0   Nov
#
#        user_rating_all  total_review_all  user_rating_recent  \
# 5733               NaN               NaN                72.0
# 71754              NaN               NaN                 NaN
# 8784               NaN               NaN                89.0
# 77128              NaN               NaN                 NaN
# 11582              NaN               NaN                82.0
#
#        total_review_recent  supported_language    price  pegi_rated  \
# 5733                  61.0                11.0  32999.0           0
# 71754                  NaN                 8.0      0.0           0
# 8784                  67.0                17.0  52000.0           0
# 77128                  NaN                 2.0      0.0           0
# 11582                102.0                 1.0   8499.0           0
#
#       age_rating  windows  mac  linux  VR
# 5733         NaN        1    1      0   0
# 71754        NaN        1    0      0   0
# 8784          16        1    0      0   0
# 77128        NaN        1    0      0   0
# 11582        NaN        1    0      0   0

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103976 entries, 0 to 121903
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   title                103975 non-null  object
#  1   developer            103976 non-null  object
#  2   publisher            103976 non-null  object
#  3   overall_reviews      103976 non-null  object
#  4   tags                 103976 non-null  object
#  5   genre                103976 non-null  object
#  6   ram                  103976 non-null  object
#  7   year                 95020 non-null   float64
#  8   month                92397 non-null   object
#  9   user_rating_all      5360 non-null    float64
#  10  total_review_all     5360 non-null    float64
#  11  user_rating_recent   41589 non-null   float64
#  12  total_review_recent  41589 non-null   float64
#  13  supported_language   94557 non-null   float64
#  14  price                95861 non-null   float64
#  15  pegi_rated           103976 non-null  int32
#  16  age_rating           16985 non-null   object
#  17  windows              103976 non-null  int32
#  18  mac                  103976 non-null  int32
#  19  linux                103976 non-null  int32
#  20  VR                   103976 non-null  int32
# dtypes: float64(7), int32(5), object(9)
# memory usage: 15.5+ MB

# %%
df_final.describe()
# Out:
#                year  user_rating_all  total_review_all  user_rating_recent  \
# count  95020.000000      5360.000000      5.360000e+03        41589.000000
# mean    2018.774626        84.747388      1.273807e+04           76.794248
# std        4.564053        11.840310      1.045024e+05           18.307801
# min     1705.000000        12.000000      1.000000e+01            0.000000
# 25%     2017.000000        80.000000      7.797500e+02           66.000000
# 50%     2019.000000        88.000000      2.198000e+03           81.000000
# 75%     2021.000000        93.000000      6.605000e+03           91.000000
# max     3021.000000       100.000000      6.464937e+06          100.000000
#
#        total_review_recent  supported_language         price  pegi_rated  \
# count         41589.000000        94557.000000  9.586100e+04    103976.0
# mean            225.190531            4.191144  6.811132e+04         0.0
# std            4642.111484            5.136509  1.362268e+05         0.0
# min              10.000000            1.000000  0.000000e+00         0.0
# 25%              18.000000            1.000000  1.749900e+04         0.0
# 50%              40.000000            2.000000  3.999900e+04         0.0
# 75%             123.000000            6.000000  8.299900e+04         0.0
# max          555285.000000           29.000000  8.784144e+06         0.0
#
#             windows            mac          linux             VR
# count  103976.00000  103976.000000  103976.000000  103976.000000
# mean        0.96228       0.255280       0.152141       0.008444
# std         0.19052       0.436021       0.359159       0.091504
# min         0.00000       0.000000       0.000000       0.000000
# 25%         1.00000       0.000000       0.000000       0.000000
# 50%         1.00000       0.000000       0.000000       0.000000
# 75%         1.00000       1.000000       0.000000       0.000000
# max         1.00000       1.000000       1.000000       1.000000

# %% [markdown]
# ## export csv

# %%
df_final.to_csv('for_EDA.csv', index=False)
